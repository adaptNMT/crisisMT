# %%
#@markdown ### Directory for results and models:
results_dir = "exp/crisismt/openai/enga/baseline" #@param {type:"string"}

from google.colab import drive
drive.mount('/content/drive')
HOME='/content/drive/MyDrive'
# Out:
# Mounted at /content/drive

# %%
HOME='/content/drive/MyDrive'

# %%
# %cd $HOME/$results_dir
# Out:
# /content/drive/MyDrive/exp/crisismt/openai/enga/baseline

# %%
# !pip install --upgrade openai
# Out:
# Collecting openai
#   Downloading openai-1.14.3-py3-none-any.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.6.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 10.7 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.14.3

# %%
import os
import openai

os.environ["OPENAI_API_KEY"] = "sk-..."
openai.api_key = os.environ["OPENAI_API_KEY"]

# %%
from openai import OpenAI
client = OpenAI()

# %%
# gpt-3.5-turbo (oringally - now swapped in my custom model)
# open the test file for reading, src-test.txt
# open the pred file for writing, pred.txt
src= open('src-test.txt', 'r')
pred = open('pred.txt', 'w')

Lines = src.readlines()
count = 0
# Strips the newline character
for line in Lines:
    count += 1
    srcl=line.strip()
    print(srcl)

    completion = client.chat.completions.create(
        model="gpt-3.5-turbo-0125",
        messages=[{"role": "system", "content": "Translate English to Irish."},
                  {"role": "user", "content": srcl}],
        temperature=0.5
    )

    translated_text = completion.choices[0].message.content
    print(translated_text) # display translations in real time
    pred.writelines(translated_text + '\n')

src.close()
pred.close()
# !ls
# Out:
# Important notice: Latest information on Revenue services and tax and customs measures in place during the COVID-19 pandemic.
# Fógra tábhachtach: Eolas is déanaí maidir le seirbhísí na gCánach agus bearta custam agus cáin atá i bhfeidhm le linn phaindéime COVID-19.
# COVID-19 information and advice for taxpayers and agents
# Eolas agus comhairle maidir le COVID-19 do cháiníocóirí agus do ghníomhaithe cáin
# Temporary COVID-19 Wage Subsidy Scheme
# Scéim Subsíde Saothair Sealadach COVID-19
# Revenue services, refunds and repayments of tax
# Seirbhísí ioncaim, aisíocaíochtaí agus aisíocadh cáin
# Filing returns, paying taxes, loss relief, debt management and debt warehousing
# Ag cur isteach ar aisíocaíochtaí, íoc cáin, leasú caillteanais, bainistíocht fiach agus stóráil fiacha.
# Compliance with certain reporting and ﬁling obligations and the satisfaction of certain other tax-related conditions
# Cumasú le riachtanais áirithe tuarascála agus aighneachtaí a chomhlíonadh agus sásamh a thabhairt do choinníollacha áirithe eile a bhaineann le cúrsaí cáin.
# VAT and customs information, including reliefs for COVID-19 speciﬁc products
# Eolas VAT agus custaim, lena n-áirítear soláthar le haghaidh táirgí COVID-19.
# Vehicle Registration Tax (VRT) and Excise
# Áirithint Taifid Gníomhaireachta (VRT) agus Cíos
# We understand the unprecedented situation facing taxpayers as a result of the COVID-19 pandemic.
# Tuigimid an suíomh gan samhail a bhaineann le cáiníocóirí mar thoradh ar phaindéim COVID-19.
# We continue to carry out our vital role as a tax and customs administration to the greatest extent possible having regard for the safety and well-being of both our staff and taxpayers.
# Leanaimid ar aghaidh ag déanamh ár ról riachtanach mar riarachán cánach agus custaim chomh fada agus is féidir agus ag tabhairt faoi deara sábháilteacht agus leas na bhfoireann agus na n-íocóirí.
# The following information, guidance and advice is available to assist taxpayers, and their agents, experiencing a range of difﬁculties caused by the impacts of the COVID-19 virus.
# Tá an t-eolas, an treoir agus comhairle seo ar fáil chun cuidiú le cáiníocóirí, agus a ngníomhaithe, atá ag fulaingt le raon deacrachtaí a bhaineann le tioncharí víris COVID-19.
# The Government announced the Employment Wage Subsidy Scheme on 23 July 2020.
# Fógraigh an Rialtas an Scéim Tacaíochta Pá na Fostaíochta ar an 23 Iúil 2020.
# The EWSS replaced the Temporary Wage Subsidy Scheme from 1 September 2020.
# Tháinig an EWSS in áit an Scéim Tacaíochta Mhaoinithe Sealadach ón 1 Meán Fómhair 2020.
# Further information on Employment Wage Subsidy Scheme (EWSS) is available from the Employing people section on this website.
# Is féidir tuilleadh eolais a fháil ar an Scéim Cúnta Íocaíochta Saothair (EWSS) ón Rannóg Fostaithe ar an suíomh gréasáin seo.
# General information
# Eolas ginearálta
# Information for employers on the Temporary COVID-19 Wage Subsidy Scheme is available from the Employing people section on this website.
# Tá eolas do fostóirí ar Scéim Subsí Cúitimh Sealadach COVID-19 ar fáil ó Rannóg Fostaithe anseo ar an láithreán gréasáin seo.
# Information  for employees on Temporary COVID-19 Wage Subsidy Scheme is available from the Jobs and pensions section on this website.
# Tá eolas ar fáil do fostaithe maidir le Scéim Deontais Sealadach COVID-19 ó Roinn Post agus Pinsean ar an suíomh gréasáin seo.
# The quickest, easiest and most convenient way for taxpayer to manage their tax is by using our online services.
# Is é an bealach is tapa, is éasca agus is éifeachtaí is féidir leis an cáiníocóir a gcáin a riar ar ár seirbhísí ar líne a úsáid.
# These wide-ranging services are available 24/7 meaning that many taxpayer interactions can continue uninterrupted.
# Tá na seirbhísí ilghnéitheacha seo ar fáil 24/7, rud a chiallaíonn go bhféadfaidh go leor comhpháirtithe cáiníochta leanúint ar aghaidh gan stad.
# Correspondence continues to be dealt with as normal.
# Leanann an chomhfhreagras a bheith á gcur i gcrích mar is gnách.
# We strongly encourage our customers, and their agents, to contact us using our secure online facility MyEnquiries rather than by telephone or post, where possible.
# Molaimid go láidir dár gcustaiméirí, agus dá n-aitheantaithe, dul i dteagmháil linn trí ár suíomh gréasáin dáilte MyEnquiries seachas trí theileafón nó tríd an bpost, más féidir.
# Due to the COVID pandemic, our public ofﬁces are closed until further notice.
# De bharr phaindéim COVID, tá ár oifigí poiblí dúnta go dtí fógra breise.
# As an alternative, the quickest and easiest way to manage your tax is by using our online services myAccount.
# Mar rogha, an bealach is gasta agus is éasca chun do cháin a bhainistiú ná ár seirbhísí ar líne myAccount a úsáid.
# If you are unable to use our online services and need a face to face meeting with us, you can make a virtual (video) appointment.
# Má tá tú neamhshásta úsáid a bhaint as ár seirbhísí ar líne agus má tá ag teastáil uait cruinniú a dhéanamh linn go pearsanta, is féidir leat coinne a dhéanamh ar líne (trí fhíseán).
# A virtual appointment means that you can arrange a video meeting with one of our service for compliance staff over a Skype for Business call.
# Ciallaíonn coinne fíorúil go bhféadfá cruinniú físe le ceann de chuid foirne seirbhíseach do chomhlíonadh a eagras ar ghuthán Skype do Ghnó.
# To facilitate an appointment, you must have:
# Chun coinne a dhéanamh, ní mór duit:
# a personal email address to receive the Skype meeting link
# seoladh ríomhphoist pearsanta chun an nasc cruinnithe Skype a fháil
# a device with a camera and microphone (for example a smartphone, laptop or tablet)
# inneal le ceamara agus micreafón (mar shampla fón póca, ríomhaire glúine nó táibléad)
# an active internet connection or a reliable 3G or 4G connection.
# nasc idirlín gníomhach nó nasc 3G nó 4G ionraic.
# As this is a data streaming service, you may be billed by your operator depending on your data package.
# Mar gur seirbhís sruthú sonraí atá i gceist anseo, is féidir go mbeifear ag cúigeadh duit de réir do phacáiste sonraí ó do oibreoir.
# If you will be accessing the virtual appointment from a:
# Má tá tú ag súil leis an coinne clárúcháin fíorúil ó:
# smartphone or tablet - you must download the Skype for Business App before your scheduled appointment.
# fón cliste nó táibléad - caithfidh tú an Aip Skype do Ghnó a íoslódáil sula mbeidh do choinne á chur i láthair.
# This app is available for free from the Apple or Google Play store.
# Tá an aip seo ar fáil saor in aisce ó stór Apple nó Google Play.
# laptop or PC - you can access it from a web browser and the link will be provided to you.
# clár ríomhaire nó ríomhaire glúine - is féidir teacht air trí bhrabhsálaí gréasáin agus cuirfear an nasc ar fáil duit.
# Beneﬁt of this service
# Leas den tseirbhís seo
# You can also have a family member or friend join you on the video call with us to help you with your enquiry.
# Is féidir le baill d' do theaghlach nó le cara bheith páirteach leat ar an ghlaoch fhíse linn chun cabhrú leat le d'fhiosrúchán.
# This option might suit if you have language difﬁculties or are an older person.
# D'fhéadfadh an rogha seo a oiriú duit más deacrachtaí teanga ort nó más duine níos sine thú.
# We will continue to prioritise the approval and processing of repayments and refunds, primarily VAT repayments and PSWT refunds, to taxpayers.
# Leanfaimid ar aghaidh ag tabhairt tosaíochta don cheadú agus don phróiseáil aisíocaíochtaí agus aisíocaíochtaí ar ais, go príomha aisíocaíochtí VAT agus aisíocaíochtaí PSWT, do cháiníocóirí.
# Where checks are necessary to allow repayment/refund claims, we will conduct these through our My Enquiries service or by telephone.
# Cá háit a bhfuil seiceálacha riachtanacha le haghaidh iarratais ar aisíocadh/aisíocadh, déanfaimid na seiceálacha sin trína ár seirbhís My Enquiries nó ar an bhfón.
# The processing of repayments and refunds is currently prioritised in the absence, due to the current circumstances relating to COVID-19, of iXBRL accounts (where applicable) as part of the Corporation Tax return for accounting periods ending on or after March 2019, subject to appropriate checks in selected cases.
# Tá tús á chur faoi láthair ar phróiseáil aisíocanna agus aisíocaíochtaí de bharr na srianta reatha a bhaineann le COVID-19, in easnamh ar chuntais iXBRL (má bhaineann) mar chuid den iontráil Cáin Corparáideach do tréimhsí cúnta a chríochnaíonn ar nó tar éis Márta 2019, faoi réir scrúduithe cuí i gcásanna roghnaithe.
# The iXBRL accounts information should continue to be returned at the earliest opportunity.
# Ba cheart go leanfaidh an t-eolas cuntas iXBRL a bheith ar ais ar an deis is luaithe.
# It should be noted that this prioritisation of repayments and refunds in the absence of iXBRL accounts will end on 30 June 2021.
# Ba cheart a thabhairt faoi deara go mbeidh an prioritisation seo ar ais i gceist le híocaíochtaí agus aisíocaí i gcás nach bhfuil cuntais iXBRL ann, agus sin ar 30 Meitheamh 2021.
# To accelerate interim refunds of Professional Services Withholding Tax (PSWT) during the Covid-19 pandemic, Revenue will accept refund claims via MyEnquiries where legible copies of the original F45 and F50 documents are attached.
# Chun an t-athbhreithniú idirimh aghaidh a thabhairt ar Cáin Teirmeach Seirbhísí Gairmiúla (CTSG) le linn phaindéim Covid-19 a luascú, glacfaidh Ioncaim le hiarratais ar ais via MoLorgánachtaí áit a bhfuil cóipíthe cléir de na cáipéisí bunaidh F45 agus F50 ceangailte.
# To ensure quicker refunds, the attached copies of the F45 and F50 documents must be tagged correctly for MyEnquiries:
# Chun a chinntiú go mbeidh aisíocaíochtaí níos tapúla, caithfear cóipíochtaí ceangailte de na doiciméid F45 agus F50 a mheaitseáil go ceart do MyEnquiries:
# Enquiry relates to 'Professional Services Withholding Tax'
# Baineann an fiosrúchán le 'Cáin Iníonadh Seirbhísí Gairmiúla'.
# All original F45 forms should be retained.
# Ba cheart fanacht ar fhoirmeacha F45 bunaidh go léir.
# A refund may be withdrawn from a taxpayer who fails to supply the original F45 documents if requested to do so by Revenue.
# Féadfar aisíoc a bhaint siar ó cháiníocóir nach n-íocann na cáipéisí F45 bunaidh ar iarraidh ó na custaiméirí a sholáthar, má iarrtar orthu é sin a dhéanamh ag an bhFiontar.
# Where the relevant F45 form cannot be issued to the speciﬁed person due solely to the current Covid-19 circumstances then, for the purposes of attachment to a MyEnquiries refund claim, a written statement issued by the accountable person to the speciﬁed person setting out the following information will be accepted in place of an F45 form:
# Má ní féidir an fhoirm F45 ábhartha a fhoilsiú don duine ar leith a bhaineann sé leis de bharr na srianta reatha Covid-19 amháin, ansin, le haghaidh ceangal le hiarratas aisíocaíochta MyEnquiries, glactar le ráiteas scríofa a fhoilsiú ag an duine atá freagrach don duine ar leith a leagann amach na sonraí seo a leanas in ionad fhoirm F45:
# Your COVID-19 vaccine
# Do le do vacsaín COVID-19
# Important information #ForUsAll
# Faisnéis tábhachtach #DúinnUilig
# The HSE is rolling out COVID-19 vaccines across Ireland, bringing hope to our communities and offering us protection from COVID-19.
# Tá an tSeirbhís Sláinte Éireann ag cur vacsaíní COVID-19 ar fáil ar fud na hÉireann, ag tabhairt dóchais dár bpobail agus ag ofráil cosanta dúinn ó COVID-19.
# This booklet tells you what you need to know about getting your COVID-19 vaccine.
# Tugann an leabhrán seo an t-eolas is gá duit a fháil faoi do vacsaín COVID-19 a fháil.
# Find out:
# Faigh amach:
# how COVID-19 spreads and its symptoms
# conas a scaipeann COVID-19 agus a síntíomaí
# Over the coming weeks and months, everyone in Ireland who is eligible will be able to receive a free COVID-19 vaccine from the HSE.
# I rith na seachtainí agus na míonna atá le teacht, beidh gach duine in Éirinn ar a bhfuil cead aige/aici in ann vacsaín COVID-19 saor in aisce a fháil ón HSE.
# Because the more people who are protected from COVID-19, the better things will be for us all.
# Mar is mó daoine atá cosanta ó COVID-19, is fearr a bheidh rudaí dúinn uile.
# How COVID-19 spreads and its symptoms
# Conas a scaipeann COVID-19 agus a bpleidhceanna
# COVID-19 is an illness that can affect your lungs and airways, and sometimes other parts of your body.
# Is galar COVID-19 é a d'fhéadfadh do do chuid scamhóga agus aeráid a bheith buailte, agus uaireanta píosaí eile den chorp freisin.
# It’s caused by a virus called SARS-CoV-2, a type of coronavirus.
# Is cuimhneachán é ag víreas darb ainm SARS-CoV-2, cineál de choróinvíreas.
# The most common way you can get COVID-19 is by coming into close contact with someone who has the virus.
# Is é an bealach is coitianta a d'fhéadfá COVID-19 a fháil ná trí teagmháil dlúth a dhéanamh le duine atá ag dul faoi bhith an víreas.
# It’s mainly spread through close contact and droplets that come from your nose and mouth.
# Is é an príomhbhunchloch é trí an dlúis agus trí bhraonacha a théann ó do shrón agus do bheola.
# COVID-19 can also spread easily in crowded or poorly ventilated areas.
# Is féidir le COVID-19 leathnú go héasca freisin in áiteanna plódaithe nó le ventailéireacht drochbhailithe.
# Because I have a health condition, getting the vaccine meant the world to me after a stressful and sometimes scary year of living through a pandemic.
# Mar gheall ar mo choinníoll sláinte, bhí an vacsaín thar a bheith tábhachtach dom tar éis bliain deacair agus uaireanta scanrúil a chaitheamh ag maireachtáil tríd an phaindéim.
# I was lucky to be able to work from home.
# Bhí an t-ádh liom go raibh mé in ann oibriú ón mbaile.
# It felt like a light at the end of a very long tunnel.
# Bhí sé mar solas ag deireadh túin fada an-tuirseach.
# a new cough - this can be any kind of cough, not just dry
# casacht nua - is féidir a bheith le haon chineál casachta, ní hamháin casacht thirim
# COVID-19 can cause anyone, at any age, serious illness, hospitalisation and even death.
# Is féidir le COVID-19 aon duine, ag aon aois, tinneas trom, ospidéalú agus fiú bás a thabhairt.
# Pregnant women, people with certain health conditions and older people have a higher risk of getting seriously ill if they get COVID-19.
# Máthairí in aghaidh, daoine le cúinsí sláinte áirithe agus daoine aosta tá riosca níos airde acu titim go dona má fhaigheann siad COVID-19.
# If you have any symptoms of COVID-19, self-isolate (stay in your room) and phone a GP (doctor).
# Má tá aon síntiúis COVID-19 ort, déan féinrialú (fan i do sheomra) agus glaoigh ar do dhochtúir.
# Your GP can arrange a COVID-19 test for you.
# Is féidir le do dhochtúir teastas COVID-19 a shocrú duit.
# How COVID-19 vaccines protect you
# Conas a chosnaíonn vacsaíní COVID-19 tú
# COVID-19 vaccines offer you protection from COVID-19.
# Soláthraíonn vacsaíní COVID-19 cosaint duit ó COVID-19.
# The surface of the virus that causes COVID-19 is studded with spikes.
# Tá spiocanna ar an dromchla den víreas a chuireann COVID-19 ina chumas.
# After your body has time to produce these antibodies, you’re less likely to get sick with COVID-19.
# Tar éis dó do chorp seal a bheith ag déanamh na n-antacántaí seo, is dóigh níos lú go mbeidh tú tinn le COVID-19.
# You’re much less likely to get seriously ill or need to go to hospital.
# Is i bhfad níos lú an seans go mbeidh ort tinn agus go mbeidh ort dul go dtí an t-ospidéal.
# It’s much safer to get immunity through your vaccination, than by getting COVID-19.
# Is é an tslí is sábháilte ná an imdhíonú a fháil trí do vacsaín, seachas COVID-19 a fháil.
# For most COVID-19 vaccines, people need 2 doses, at separate times, to get longer lasting protection.
# Chun cosaint fhada a fháil, bíonn an ghá le 2 dhaingniú de vacsaíní COVID-19, ag amanna éagsúla.
# If you had COVID-19 in the last 6 months, you only need 1 dose of a vaccine.
# Má bhí COVID-19 agat le 6 mhí anuas, níl ach 1 dós den vacsaín de dhíth ort.
# You can get the COVID-19 vaccine if you’re breastfeeding.
# Is féidir leat an vacsaín COVID-19 a fháil má tá tú ag breasluachan.
# If you’re pregnant, talk to your obstetrician or GP about getting your COVID-19 vaccine.
# Má tá tú ag súil le leanbh, labhair le do obstraitheoir nó le do dhochtúir teaghlaigh faoi do vacsaín COVID-19.
# If you already had COVID-19
# Má tá COVID-19 agat cheana féin
# Your vaccine reduces your risk of getting COVID-19 again.
# Laghdaíonn do vacsaín do riosca bheith agat ar ais ag fáil COVID-19.
# Your vaccine cannot give you COVID-19
# Ní féidir le do vacsaín tabhairt duit COVID-19
# If you get COVID-19 soon after your vaccination, it’s possible you caught it before your appointment.
# Má fhaighidh tú COVID-19 go luath tar éis do vacsaín, is féidir go bhfuair tú é roimh do choinne.
# Registering when it’s your turn
# Cláraigh nuair a bhíonn sé do chuid iarrtha.
# The HSE will let you know when it’s your turn to register through www.hse.ie, news or public advertising.
# Inisfidh an tSeirbhís Sláinte Éireann duit nuair a bheidh sé in am duit clárú trí www.hse.ie, nuacht nó fógraí poiblí.
# Most people need to register online at www.hse.ie to get their free COVID-19 vaccine at a HSE vaccination centre.
# Caithfidh formhór daoine clárú ar líne ag www.hse.ie chun a vacsaín COVID-19 saor in aisce a fháil ag ionaid vacsaíne an HSE.
# Please do not register until it’s your turn.
# Ná rith duit go dtí go bhfuil sé do chuid dul.
# Call the COVID-19 helpline on 1850 24 1850 to register by phone instead.
# Glaoigh ar an líne tacaíochta COVID-19 ar 1850 24 1850 chun clárú ar an bhfón in ionad sin.
# When it’s your turn, visit vaccine.hse.ie to register.
# Nuair a bheidh sé i do cheann, cuardaigh vaccine.hse.ie chun clárú.
# Click ‘Start now’ and choose your group - at busy times, there may be a queue.
# Cliceáil ar 'Tosaigh anois' agus roghnaigh do ghrúpa - ag amanna gnóthacha, b'fhéidir go mbeidh sraitheanna ann.
# Create your account - you will receive a verification email.
# Cruthaigh do chuntas - gheobhaidh tú ríomhphost de chreidiúnú.
# Click on the link in the verification email - you then get a verification text (SMS).
# Cliceáil ar an nasc sa ríomhphost de dhíth - ansin faighfidh tú téacs de dhíth (SMS) leis an deimhniú.
# Enter your personal details - read why the HSE asks for this information at www.hse.ie
# Cuir isteach do mheastacháin pearsanta - léigh cén fáth a bhfuil an tseirbhís sláinte agus leighis ag iarraidh an eolas seo ag www.hse.ie.
# This tells you the date, time, HSE vaccination centre to go to and which vaccine you’re getting.
# Insíonn sé duit an dáta, an t-am, an t-ionad vacsaínithe HSE a theacht chuige agus céard é an vacsaín atá á fháil agat.
# The HSE only uses COVID-19 vaccines that the European Medicines Agency (EMA) has approved.
# Ní úsáideann an tseirbhís sláinte poiblí vacsaíní COVID-19 nach bhfuil cheadaithe ag an Eagraíocht Eorpach um Acmhainní Leigheas (EMA).
# While COVID-19 vaccine development moved fast, the vaccines have gone through the same steps as all licensed medicines.
# Cé go ndeachaigh forbairt vacsaín COVID-19 go tapa, chuaigh na vacsaíní tríd na céimeanna céanna le gach leigheas atá ceadaithe.
# three phases of clinical trials with tens of thousands of people
# trí chéim de thriailanna cliniciúla leis na mílte duine
# The EMA then scientifically evaluated and authorised the COVID-19 vaccines for use in Europe.
# Ansin rinne an EMA measúnú eolaíoch agus údaraithe ar vacsaíní COVID-19 chun úsáid in Eoraip.
# More information on how COVID-19 vaccines are approved is available at www.ema.europa.eu
# Tá tuilleadh eolais faoin gcaoi a dtagraítear vacsaíní COVID-19 ar fáil ag www.ema.europa.eu
# There was huge global investment into researching and developing the vaccines.
# Bhí infheistíocht mhór idirnáisiúnta i mbun taighde agus forbairt na vacsaíní.
# A lot of people had COVID-19 when they were developed, so scientists could learn quickly that they’re effective.
# Bhí go leor daoine ag dul trí COVID-19 nuair a cuireadh i bhfeidhm iad, mar sin d'fhéadfaí do na heolaithe foghlaim go tapa go bhfuil siad éifeachtach.
# Millions of people have received COVID-19 vaccines all over the world.
# Tá na milliúin daoine tar éis vacsaíní COVID-19 a fháil ar fud an domhain.
# There’s strong, reliable evidence that COVID-19 vaccines greatly reduce your risk of getting COVID-19.
# Tá fianaise láidir, dílis ann go mbíonn tionchar mór ag vacsaíní COVID-19 ar do riosca bheith agat ar COVID-19.
# They’re highly effective at preventing deaths and serious illness from COVID-19.
# Is cumhachtach iad ag cur cosc ar bháis agus ar ghalair thréigthe ó COVID-19.
# In Ireland alone, we’re already seeing reduced illness and fewer deaths among people who are vaccinated.
# In Éirinn amháin, táimid ag breathnú ar laghdú ar ghalair agus ar líon na mbásanna i measc daoine a bhfuil vacsaín orthu cheana féin.
# It monitors the safety and effectiveness of COVID-19 vaccines after they’re approved for use.
# Múnaíonn sé sábháilteacht agus éifeachtacht vacsaíní COVID-19 tar éis a ghlacadh do úsáid.
# Like all medicines, vaccines can cause side effects.
# Mar sin féin, d'fhéadfadh vacsaíní go léir tuairimí a bheith acu.
# When you’re getting vaccinated, the HSE gives you a detailed leaflet with information about possible side effects of your vaccine.
# Nuair atá tú á vaccínáil, tugann an tSeirbhís Sláinte (HSE) bileog mionsonraithe duit a bhfuil eolas ann faoi na modhanna cumhachta is féidir a bheith ag do vacsaín.
# The vaccines are new and information about long-term side effects is limited.
# Is iad na vacsaíní nua agus tá eolas teoranta faoi thaobh fad-téarma de thaobh na taobhghníomhaíochta.
# As with all vaccines, you can report suspected side effects to the Health Products Regulatory Authority (HPRA) at www.hpra.ie/report
# Mar a bhaineann sé le vacsaíní uile, is féidir leat tuairimí a chur in iúl maidir le hairíonna diúltacha don Údarás Rialála Táirgí Sláinte (HPRA) ag www.hpra.ie/report
# As more people get vaccinated, more information becomes available.
# Agus nuair a fháiltear roinnt níos mó daoine le vacsaín, éireoidh níos mó eolas ar fáil.
# When you arrive, follow the signs or instructions from the stewards.
# Nuair a shroichann tú, lean na comharthaí nó treoracha ó na stiúrthóirí.
# The vaccinator gives you the COVID-19 vaccine as an injection in your upper arm.
# Cuireann an vacsaínitheoir an vacsaín COVID-19 ort mar inite san uachtar uachtarach.
# Go to the observation area before you leave
# Téigh go dtí an limistéar breathnaithe sula imeoidh tú
# Getting your COVID-19 vaccine reduces your risk of getting COVID-19 and protects you from serious complications of the illness.
# Trí bhur vacsaín COVID-19 a fháil, laghdaítear bhur riosca COVID-19 agus cosnaítear sibh ó chomplaicí tromchúiseacha na galar.
# people who are not vaccinated from 1 other household - as long as no one from that household is at high risk from COVID-19
# daoine nach bhfuil a vacsaíneadh ó theach eile amháin - ar an gcaoi nach bhfuil aon duine ón teaghlach sin i mbaol mór ó COVID-19
# Close contacts
# Teagmhálacha gar.
# If you’re a vaccine protected close contact of a person who tests positive for COVID-19, you do not need to:
# Má tá tú mar dhuine a bhfuil cosaint vacsaín agat agus atá i dteagmháil dlúth le duine a thástálann dearfach do COVID-19, ní gá duit:
# be tested for COVID-19
# Tabharfaidh sé tástáil do COVID-19
# If you’re immunocompromised, the contact tracing team will advise you what you need to do.
# Má tá do chóras imdhíonachta laghdaithe, tabharfaidh foireann trasphéireachta teagmhaíocht comhairle duit faoi cad is gá duit a dhéanamh.
# Pfizer/BioNTech
# Pfizer/BioNTech - Pfizer/BioNTech
# 7 days after 2nd dose
# 7 lá tar éis an dara dáis
# Moderna
# Moderna
# 14 days after 2nd dose
# 14 lá tar éis an dara dáis
# AstraZeneca
# AstraZeneca
# 28 days after 1st dose - you still need to get your 2nd dose
# 28 lá tar éis an chéad dhuine - tá fós ag teastáil uait do dhuine 2.
# Janssen
# Janssen
# 14 days after single dose
# 14 lá tar éis an dá leagan aonair
# If you had COVID-19 in the last 6 months, confirmed with a laboratory test, you can also follow the vaccine bonus advice - unless you’re aged 65 or older or you’re immunocompromised.
# Má bhí COVID-19 agat leis an 6 mhí dheireanach, a dhearbhaíodh le tástáil saoránachta, is féidir leat comhairle bónais an vacsaín a leanúint chomh maith - ach amháin más tú 65 nó níos sine nó má tá do chóras imdhíonachta laghdaithe.
# Many of our older patients, and those with chronic medical conditions, have had to give up so much.
# Tá go leor dár gcinnteoirí aosta, agus iad siúd le coinníollacha leighis chrónacha, buartha faoi conas a bhfuil orthu titim ar aghaidh.
# We’re so proud to help them get back to enjoying their life to the full.
# Táimid chomh brodúil go bhfuil muid in ann cuidiú leo filleadh ar a saol agus taitneamh a bhaint as go hiomlán.
# Now that almost all of our over 70s are vaccine protected, it’s lovely to hear them making plans - catching up with their friends, getting their hair done or simply hugging their grandchildren.
# Anois go bhfuil beagnach gach duine os cionn 70 bliain d'aois againn faoi chosaint vacsaín, tá sé deas cloisteáil iad ag déanamh pleananna - ag tabhairt aghaidh ar a gcairde, ag fáil a gcuid gruaige déanta nó ag tabhairt faoi ghrá a gcuid garpháistí.
# Most people are aware of the dangers posed by COVID-19 and the overwhelming scientific evidence in favour of vaccination.
# Is eol do chuid daoine go bhfuil an-imní orthu faoina bhfuil COVID-19 ag cur i mbaol orthu agus an fhianaise eolaíochta tromchúiseach ar son na vacsaíní.
# There have been some questions about side effects.
# Tá roinnt ceisteanna faoi thaimpactí taobh istigh.
# For example, the vaccine against measles, mumps and rubella (MMR) is highly effective at preventing disease.
# Mar shampla, tá an vacsaín in aghaidh an mheisil, an mhampla agus an rubéola (MMR) an-éifeachtach ag cosc ar an ngalar.
# In some circumstances, a person can still get a disease even after receiving the recommended doses of a vaccine against it.
# I roinnt cásanna, is féidir le duine fós galar a fháil fiú tar éis na doiscíní molta de vacsaín in aghaidh a fháil.
# Each virus and bacterium triggers a unique response in the immune system involving a specific set of cells in the blood, in the bone marrow and all over the body, called T-cells, B-cells, among others.
# Déanann gach víreas agus baictéar freagra uathúil a chumhdaíonn córas imdhíonachta a bhaineann le sraith áirithe cella sa fhuil, sa mharbhrann agus ar fud an choirp, a dtugtar T-cells, B-cells, i measc daoine eile orthu.
# A vaccine stimulates an immune response, and a ‘memory’ of the body to a specific disease, without causing the disease.
# Cuireann vacsaín freagairt imdhíonach ar bun agus ‘cuimhne’ ar an gcorp maidir le galair áirithe gan an galar a chur ar bun.
# Most vaccines contain a greatly weakened or an inactivated (killed) form of a virus or bacterium that usually causes a disease, or a small part of the virus or bacterium.
# Bíonn foirm an-tábhachtach nó formáilte (marbh) go mór i bhformhór na vacsaíní a bhíonn ann, a thagann de ghnáth ó víreas nó baictéar a chuireann galar i bhfeidhm, nó cuid beag den víreas nó baictéar.
# When a person is given the vaccine, their immune system recognises the antigen as ‘foreign’.
# Nuair a thugtar an vacsaín do dhuine, aithníonn a gcóras imdhíonach an antaigean mar 'gur eachtrannach' é.
# Later, if the person comes into contact with the actual infectious virus or bacterium, their immune system will ‘remember’ it.
# Níos déanaí, má théann an duine i dteagmháil leis an víreas nó an baictéar aicmiúil, cuimseoidh a chóras imdhíonach é.
# Immunity usually lasts for years, and sometimes for a lifetime.
# Bíonn imdhíonacht ann go minic ar feadh blianta, agus uaireanta ar feadh an tsaoil.
# Immunity through vaccination protects not only the immunised individual but also protects unvaccinated people in the community, such as infants who are too young to be vaccinated.
# Cosaint trí vacsaíní ní dhéanann sé cosaint amháin ar an duine a vacsaítear ach cuireann sé cosaint ar dhaoine neamh-vacsaíteacha sa phobal freisin, ar nós leanaí nach bhfuil siad go leor d'aois chun vacsaín a fháil.
# In contrast, a person who becomes immune by getting the disease can expose other unvaccinated people to the disease.
# Ar aghaidh, d'fhéadfadh duine a fhaigheann imdhíon trí mheas a fháil ar an galar duine eile a bheith in ann an galar a dhíchumasú.
# Some newer vaccines do not contain an antigen.
# Níl aon antaigin i roinnt vacsaíní nua.
# These instructions can be:
# Is féidir na treoracha seo a bheith:
# mRNA in an mRNA vaccine; or a modified, harmless virus, in a viral-vector vaccine.
# mRNA in ollmhíniú mRNA; nó víreas athraithe, neamhionfhabhtaithe, in ollmhíniú víris-veictéir.
# When a person is given an mRNA or a viral-vector vaccine, some of their cells read the instructions.
# Nuair a thugtar vacsaín mRNA nó víreas-veicteir do dhuine, léann roinnt de a gcuid cealla na treoracha.
# The person’s immune system then recognises the antigen as ‘foreign’, activating immune cells and making antibodies.
# Ansin a aithníonn córas imdhíon an duine an antóigin mar 'eachtrannach', ag gníomhú comhpháirteanna imdhíonacha agus ag déanamh antaibheoirí.
# In addition to one or more antigens, there could be other components in a vaccine, depending on the type of vaccine.
# Chomh maith le haon nó níos mó antiogaine, d'fhéadfadh go mbeadh comhpháirteanna eile i vacsaín, de réir mar aon le cineál vacsaíne.
# stabilisers: to keep vaccine components stable;
# stabilizáidí: chun coinníollacha an vacsaín a chothabháil;
# adjuvants: these improve the immune response to the vaccine by making the response stronger, faster and more sustained over time – an example of which is aluminium;
# adjuvants: cuireann siad leis an bhfreagairt imdhíonach do na vacsaín trí dheisiú na freagairt a dhéanamh níos láidre, níos tapa agus níos fada ar feadh ama - sampla de sin is ea alumíniam;
# excipients: these are inactive ingredients, like water, or sodium chloride (salt), as well as preservatives or stabilisers that help the vaccine remain unchanged during storage, keeping it active.
# coimhleacsaithe: seo na comhábhair neamhghníomhacha, cosúil le huisce, nó clóiríd sóidiam (salann), chomh maith le coimeádaithe nó seasmhachtaí a chuidíonn leis an vacsaín a choinneáil neamhathraithe le linn stórála, ag coinneáil é gníomhach.
# All vaccine components are consistently controlled to ensure they are present at levels that have been shown to be safe.
# Déantar rialú cothrom ar gach comhábhar vacsaíne chun a chinntiú go bhfuil siad i láthair ag leibhéil a thugtar amach go bhfuil siad sábháilte.
# In some types of vaccines there could also be trace amounts of other substances used in the manufacturing process, such as ovalbumin (a protein found in eggs) or neomycin (an antibiotic).
# In ábhartha vacsaíní áirithe, d'fhéadfaí líon beag tráchtála d'ábhartha eile a úsáidtear i bpróiseas an bhunú, cosúil le ovalbumin (próitéin atá le fáil i gcnúis) nó neomycin (antibiátach).
# Whenever these substances are present at a level that might trigger a reaction in a sensitive or allergic individual, their presence is declared in the information provided to healthcare workers and patients about the vaccine.
# Nuair atá na substaintí seo i láthair ag leibhéal a d'fhéadfadh tionchar a bheith acu ar duine a bhfuil gaireas nó ailléirgeach dóibh, déantar a láithriú sa fhaisnéis a sholáthraítear d'oibrithe sláinte agus do bhaill foirne faoi an vacsaín.
# Individual European countries decide which vaccines should be part of their national vaccination programmes and funded by their national health systems.
# Is cinneadh ag tíortha Eorpacha aonair cé acu a cheart go mbeadh vacsaín i measc a gclár vacsaínithe náisiúnta agus a mbeadh maoinithe ag a gcórais sláinte náisiúnta.
# Most national vaccination programmes in the EU/EEA include vaccines for up to twenty diseases which are given to people at specific ages.
# Is iad cláracha vacsaínithe náisiúnta is mó i dTionóil na hEorpa/Aontas Eorpach na nEagraíochtaí Eorpacha Eacnamaíochta, agus cuirtear vacsaíní in aghaidh suas le fiche galar ar leith chuig daoine ag aoisanna áirithe.
# Some vaccines protect against only one disease, but others protect against more than one.
# Cosnaíonn roinnt vacsaíní in aghaidh ach amháin galar, ach cosnaíonn daoine eile in aghaidh níos mó ná ceann amháin.
# For more information about national vaccination programmes, see the ECDC vaccine scheduler
# Chun tuilleadh eolais faoi chláir vacsaínithe náisiúnta, féach ar scéalaí vacsaíní an ECDC
# and visit the official websites on immunisation of the EU/EEA countries here.
# agus cuairt a thabhairt ar na suíomhanna gréasáin oifigiúla maidir le himiúnú sna tíortha AE/AEE anseo.
# What is HPV?
# Cad is ea HPV?
# Human papillomavirus (HPV) infection is a viral infection that is mainly sexually transmitted by direct contact with an infected person.
# Is ionfhabhtú víreasach é ionfhabhtú papillomavirus an duine (HPV) a dhéantar a chur trasna go príomha trí chontacht dhíreach le duine a bhfuil an víreas ionfhabhta acu.
# There are more than 100 types of HPV viruses.
# Tá breis agus 100 cineál vírisí HPV ann.
# symptoms smaller illustration
# rialú beag nó síntiúis beag a bhaineann leis
# What are the symptoms of HPV?
# Cad iad na mothúcháin a bhaineann le HPV?
# In most cases, an HPV infection disappears on its own without causing any obvious symptoms or problems.
# I gcásanna móra, imíonn galar HPV go hé féin gan aon comharthaí nó fadhbanna soiléir a chur ina luí.
# What are the complications of HPV?
# Cad iad na deacrachtaí a bhaineann le HPV?
# If HPV does not go away it may cause:
# Má fhanann HPV ann, d'fhéadfadh sé a bheith ina chúis le:
# cervical or other types of cancer (e. vulvar, vaginal, anal penile, and some cancers of the head and the neck)
# caidreamhach nó cineálacha eile ailse (m. vulvar, vaginal, anal, peileas, agus cuid de chuid na gceirdeanna agus na ceann)
# genital and anal warts
# creachadh agus bollacha anala
# couple illustration
# illustráidh pósta
# How is HPV spread?
# Conas a scaipeann HPV?
# HPV is transmitted by direct contact, mainly sexual, with someone who has the virus.
# Clúdaítear HPV trí dhéileáil díreach, go príomha trí chomhfhreagras, le duine atá agus an víreas.
# Who is at risk of HPV?
# Cé atá i mbaol HPV?
# Anyone who is sexually active is at risk of contracting HPV.
# Tá gach duine atá gníomhach go gnéasach i mbaol HPV a fháil.
# How can HPV be prevented?
# Conas is féidir HPV a chosc?
# Vaccination of girls and boys against HPV can prevent HPV infections and consequently HPV-related diseases in both sexes, including genital and anal warts, cervical cancer and other cancers caused by HPV.
# Is féidir le vacsaíní a thabhairt do chailíní agus buachaillí in aghaidh HPV a chosc ar ghalar HPV agus, mar thoradh air sin, ar ghalaranna gaolmhara HPV ina dhá inscne, lena n-áirítear martaí ginealaigh agus anal, ailse ceirbiceach agus ailseanna eile a chuirtear ar bun ag HPV.
# The use of condoms is not 100% effective in preventing the transmission of the virus.
# Níl úsáid na gcaidreamhí 100% éifeachtach i ngan fháil ar leithdháileadh an víris a sheachaint.
# How is HPV treated?
# Conas a leigheasann HPV?
# There is no treatment for the virus itself, but the health problems caused by HPV can be treated in different ways.
# Níl aon cóireáil ar fáil don víreas féin, ach is féidir le fadhbanna sláinte a chuireann HPV in iúl a bheith inmharthana a chóireáil ar bhealaí éagsúla.
# Cervical cancer and tissue in the cervix that is described as ‘precancerous’ can be identified early through cervical cancer screening and treated.
# Is féidir ailse ceirbheacs agus fíochán sa cheirbheacs a bhfuil tagairt dá dtéiteáil mar ‘réamhchúraim’ a aithint go luath trí scagadh ailse ceirbheacs agus a leigheas.
# What is measles?
# Cad é measles?
# Measles is a highly contagious viral disease that can be contracted at any age, and that can spread widely.
# Is galar víreasach an-choitianta é an measles is féidir é a fháil ag aon aois agus is féidir é a scaipeadh go fairsing.
# What are the symptoms of measles?
# Cad iad na síntíomaithe de bhíonach?
# Measles symptoms usually appear after 10-12 days of infection:
# Bíonn comharthaí measair agus méadaitheachtaí agus méadaitheachtaí measair a bhíonn tar éis 10-12 lá tar éis an ghalair a bheith ann:
# initial symptoms resemble a cold with a runny nose, cough and a mild fever;
# Tá síntiúis tosaigh cosúil le slaghdán le sruthbhualadh, casacht agus fiabhras éadrom;
# the eyes become red and sensitive to light;
# Éiríonn na súile dearg agus fuar ag solas;
# On the third to seventh day, the temperature may reach up to 41 ⁰C;
# Ar an tríú go dtí an seachtú lá, d'fhéadfadh an teocht dul suas go dtí 41 ⁰C;
# A red rash lasting four to seven days begins on the face and then spreads over the entire body;
# Tosaíonn deargfholtas a bhíonn ann ar feadh ceithre go seacht lá ar an aghaidh agus scaipeann sé ansin ar fud an chorp.
# Small white spots may also appear on the gums and the inside of the cheeks.
# D'fhéadfadh spotanna bána beaga a bheith ar an ngéag agus laistigh den ghearrán freisin.
# What are the complications of measles?
# Cad iad na comhlachtaí a bhaineann leis an measles?
# 30% of children and adults infected with measles can develop complications.
# Is féidir go mbeadh comharthaíocht ann i 30% de pháistí agus daoine fásta a bhfuil scarlatín orthu.
# complication illustration
# íomhá comhbhrúite
# Pneumonia is a potential serious complication that has led to the death of some measles patients.
# Is féidir pneumonia a bheith mar gheallghort thar a bheith tromchúiseach a d'fhág go bhfuil roinnt othar measles tar éis bás a fháil.
# The mortality rate for measles is 1-3 persons per 1 000 cases and highest in those younger than five years of age and among immunocompromised individuals.
# Is é an ráta bháis do bhéilíní 1-3 duine in aghaidh gach 1 000 cás agus is airde i measc iad siúd atá níos óige ná cúig bliana d'aois agus i measc daoine atá le córas imdhíonachta.
# About 1 measles patient in 1 000 develops inflammation of the brain tissue (encephalitis), a condition that results in permanent neurological disability in approximately one of four cases.
# Is é thart ar 1 othar fríd 1,000 a fhorbairt aillse na inchinn (encefalaítis), coinníoll a bhaineann amach míchumas neorálta buan i gcásanna thart ar cheithre amach de gach cás.
# Very rarely, a persistent measles virus infection can produce subacute sclerosing panencephalitis (SSPE), a disease in which nerves and brain tissue degenerate progressively and which is more likely to appear if measles infection occurs at a younger age.
# Go minic, is féidir leis galar víreas measles atá leanúnach tinnis SSPE (subacute sclerosing panencephalitis) a tháirgeadh, galar ina bhfuil neirbhíseacha agus snáithidí inchinn ag dul i léig go héifeachtach agus is dócha go mbeidh sé níos coitianta dul i bhfeidhm má tharlaíonn tinneas measles ag aois níos óige.
# How is measles spread?
# Conas a scaipeann frithghiniúint?
# The measles virus is spread via airborne droplets produced when the infected person coughs and sneezes.
# Scaipeadhann víreas na measles trí boladháin aeir a dhéantar nuair a dhéanann an duine a bhfuil an galar air casacht agus sraothair.
# Measles spreads easily among unvaccinated individuals.
# Scaoilteann teasairc go héasca i measc daoine nach bhfuil vacsaín orthu.
# Who is at risk of measles?
# Cé atá i mbaol de dhealú na meislí?
# Anyone who is not vaccinated against measles or who has not had the disease is at risk of getting measles at any age.
# Tá gach duine nach bhfuil vacsaínithe in aghaidh na meilise nó nach bhfuil an galar sin aige i mbaol meilise a fháil ag aon aois.
# How can measles be prevented?
# Conas is féidir scarlach a chosc?
# The only protection against measles is vaccination.
# Is é an t-aon cosaint in aghaidh na measles ná vacsaínú.
# Two doses of the vaccine are needed for maximum protection.
# Tá dhá dhóis den vacsaín de dhíth chun cosaint uasmhéide a bhaint amach.
# The MMR vaccine may be given earlier in life during outbreaks.
# Is féidir an vacsaín MMR a thabhairt níos luaithe sa saol le linn scagadh.
# How is measles treated?
# Conas a leigheasann measles?
# There is no specific treatment for measles.
# Níl aon cóireáil áirithe ann do dhealúis.
# A variety of measures are employed to avoid the further spread of measles, such as quarantine from school or work for both the ill person and those close contacts with uncertain vaccination status.
# Úsáidtear réimse beartais chun scaradh leathanaigh na meala, cosúil le cuarantín ón scoil nó ón obair do dhaoine atá tinn agus dá gcairde a bhfuil stádas vacsaínithe neamhbhrí acu.
# Antibiotics are not effective against measles because it is caused by a virus.
# Níl antaibheathach as úsáide in aghaidh an measles mar gur víreas a chuireann sé ina choinne.
# What is pertussis?
# Cad é an pertussis?
# Pertussis is a highly infectious bacterial disease involving the lungs and airways.
# Is galar bactéarach ard-ghalarach é an pertúis a bhaineann leis na scamhóga agus na sléibhte aeir.
# What are the symptoms of pertussis?
# Cad iad na mothúcháin a bhaineann le pertussis?
# Symptoms usually appear 7 to 10 days after infection, but may also appear up to 21 days later:
# Bíonn na síntíomaí de ghnáth le feiceáil 7 go 10 lá tar éis aitheanta, ach d'fhéadfadh siad freisin a bheith ann suas le 21 lá níos déanaí:
# Initially, symptoms resemble those of a common cold (sneezing, runny nose, low-grade fever and a mild cough).
# Ar dtús, tá síntí cosúil le ghalair an fhliúch (sraothartach, scamhóg, fiabhras íseal agus casacht bhog).
# Within two weeks, the cough becomes more severe and is characterized by episodes of numerous rapid coughs, followed by a crowing or high-pitched ‘whoop’.
# I gceann dhá sheachtain, éiríonn an casacht níos measa agus is léir go bhfuil radharcanna de mhórán casacht tapa ann, a leanann de chraos nó de ‘whoop’ ard.
# In young infants the typical 'whoop' may never develop, and the coughing fits may be followed by brief periods when breathing stops.
# Is féidir nach bhforbróidh an 'whoop' tíogarach i ngasúir óga, agus d'fhéadfadh go leanfaí na géarchéimeanna casacht le tréimhsí gairid ina dhiaidh nuair a stopann an t-análú.
# Adolescents, adults, or children partially immunised generally have milder or somewhat different symptoms.
# Bíonn síntiúis níos éadroma nó níos éagsúla de ghnáth i leanaí, daoine fásta nó daoine óga atá leathghníomhaíoch go parcial.
# What are the complications of pertussis?
# Cad iad na deacrachtaí a bhaineann le pertussis?
# The most severe forms of pertussis are in infants.
# Is iad na foirmeacha is measa de pertussis i ngasúir.
# In adults and older children, complications include inability to breathe for short periods, broken ribs, rectal prolapse and hernias.
# I measc daoine fásta agus daoine níos sine, is iad na bagairtí a bhaineann le neamhshuim saol a tharraingt, cnaipí briste, prolaps rectal agus hernias.
# How is pertussis spread?
# Conas a scaiptear pertussis?
# Pertussis is spread via airborne droplets produced when the infected person coughs.
# Leárlaith an pertúis trí dréachtscamaill atá cruthaithe nuair a bhíonn an duine a bhfuil an galar air ag casacht.
# Who is at risk of pertussis?
# Cé atá i mbaol de phertúsa?
# Anyone who is not vaccinated with the pertussis vaccine, or whose vaccination status is not up-to-date, is at risk of contracting the disease.
# Tá daoine ar bith nach bhfuil vacsaínítear in aghaidh vacsaín phertúsa, nó atá a stádas vacsaínithe neamhghnáth, i mbaol dul i gcion ar an ngalar.
# How can pertussis be prevented?
# Conas is féidir scarlatina a chosc?
# The most important way to prevent pertussis is through complete immunisation.
# Is é an bealach is tábhachtaí chun scarlatina a chosc ná trí vacsaín iomlán a fháil.
# Some EU/EEA countries recommend boosters for adolescents, adults, and/or women during pregnancy, which also temporarily protects the baby once it is born.
# Moltaítear iad i gcuid de thíortha AE/AEE maidir le dhaingniú a thabhairt do dhéagóirí, do dhaoine fásta, agus/nó do mhná i rith toirchis, rud a chosnaíonn an leanbh go sealadach nuair a thagann sé chun baile.
# How is pertussis treated?
# Conas a dtreitear pertussis?
# Antibiotics can be used to treat pertussis and prevent further spread of the disease.
# Is féidir le himoibicitéirí a úsáid chun pertúis a leigheas agus leathnú na galar a chosc.
# What is rubella?
# Cad é rubella?
# Rubella (German measles) is a viral infection.
# Is galar vírisach é rubella (coróinvíreas Gearmánach).
# Symptoms of rubella
# Fianaise de ruibheola
# What are the symptoms of rubella?
# Cad iad na comharthaí de rubella?
# Up to 50% of people infected with rubella do not experience symptoms. When symptoms do occur, they include:
# Ní mhothaíonn suas le 50% de dhaoine a bhfuil rubella orthu aon síntiúis. Nuair a thagann síntiúis chun cinn, áirítear leo:
# red rash;
# dearg éadach;
# swollen lymph glands around the ears and the back of the head;
# glandaí lymphach a bhfuil ina mbéalta thart ar an gcluas agus ar chúl an cheann;
# pain and inflammation of the joints in adults.
# tinneas agus fliúirse na n-aontas i measc daoine fásta.
# What are the complications of rubella?
# Cad iad na deacrachtaí a bhaineann le rubella?
# The consequences for unvaccinated pregnant women that get rubella are particularly severe, due to the likelihood that contracting the disease during pregnancy can lead to miscarriage or CRS in their babies.
# Is tábhachtach go mór na himpleachtaí do mhná a bhfuil siad gan vacsaín in aghaidh rubella agus a fháil ar an ghalair, mar gheall ar an dóigh a bhfuil sé i bhfad níos tromchúiseach nuair a fhéadann an ghalair a fháil le linn toirchis go bhfuil an baol ann go dtiocfaidh mí-mheáchanlú nó CRS ina bpáistí mar thoradh air.
# How is rubella spread?
# Conas a scaipeann rubella?
# The rubella virus is spread via airborne droplets produced when the infected person coughs and sneezes.
# Scaoiltear víreas rubella trí ghéarchéimnéil aeráide a chruthaítear nuair a bhíonn an duine a bhfuil an víreas ann ag casacht agus ag sraothartú.
# Who is at risk of rubella?
# Cé atá i mbaol ruibéola?
# Anyone who has not had the disease or who has not been vaccinated with the MMR vaccine is at risk of contracting rubella.
# Tá daoine ar bith nach bhfuil an galar acu nó nach bhfuil siad vacsaínithe leis an vacsaín MMR i mbaol rubella a fháil.
# How can rubella be prevented?
# Conas is féidir scarláin a chosc?
# The only protection against rubella is vaccination.
# Is é an t-aon cosaint in aghaidh rubella ná vacsaínú.
# Women who plan to become pregnant should check their vaccination status, as they cannot be vaccinated against rubella during pregnancy.
# Ba cheart do mhná a bhfuil plean acu le clann a bheith acu a dhaingniú a gcumas vacsaínithe, mar ní féidir iad a vacsaíniú in aghaidh rubella le linn toirchis.
# How is rubella treated?
# Conas a leigheasann rubella?
# There is no specific treatment for rubella.
# Níl aon cóireáil áirithe ann do rubella.
# When looking at health-related information, it can be difficult to judge the quality and accuracy of information found.
# Nuair a bhíonn tú ag breathnú ar fhaisnéis a bhaineann le sláinte, b'fhéidir nach mbeidh sé éasca meas a dhéanamh ar chaighdeán agus cruinneas na bhfaisnéise a aimsítear.
# People may wonder where to find accurate information, who is behind the development of the information they find, and also if the information is supported by scientific evidence.
# D'fhéadfadh daoine a bheith ag smaoineamh cá bhfuil eolas cruinn le fáil, cé hí an té atá taobh thiar den fhorbairt ar an eolas a aimsiú siad, agus freisin má tá an eolas tacaithe ag fianaise eolaíochta.
# This section provides links to the websites of other health organisations both at national and international level, in order to facilitate access to trusted sources of information, such as:
# Cuireann an rann seo naisc chuig suiomhanna eile eagraíochtaí sláinte, ar leibhéal náisiúnta agus idirnáisiúnta, chun an t-ábhar faisnéise a bhfuil muiníne ann a fháil go héasca, mar shampla:
# The Vaccine Safety Net
# An Gréasán Sábháilteachta Vacsaíní
# The Vaccine Safety Net (VSN) is a global network of websites, established by the World Health Organization, that provides reliable information on vaccine safety.
# Is líonra domhanda suaitheantas Vacsaín Slándála (VSN) é an Vaccine Safety Net, a bhunaigh an Eagraíocht Dhomhanda Sláinte, a chuireann eolas iontaofa ar shábháilteacht vacsaín ar fáil.
# This video is available in 24 EU languages.
# Tá an físeán seo ar fáil i 24 teanga AE.
# ...
# Most COVID-19 vaccines trigger these immune responses to a tiny fragment of SARS-CoV-2.
# Déanann formheasaimhí COVID-19 chomhfhreagrasanna imdhíonacha seo a bhaint amach ar phíosa beag de SARS-CoV-2.
# If a person who has received a COVID-19 vaccine is infected by the virus later on, the immune system recognises the virus.
# Má bhíonn duine a fuair vacsaín COVID-19 agus a fháilíonn galar den víreas ina dhiaidh sin, aithníonn an córas imdhíonachta an víreas.
# Because it is already prepared to attack the virus, that person’s immune system is able to protect them from COVID-19 disease.
# Mar gur réidh leis an víreas a ionsaí, is féidir le córas imdhíonachta an duine sin iad a chosaint ó ghalair COVID-19.
# See more information on How vaccines work.
# Feice tuilleadh eolais ar Conas a oibríonn vacsaíní.
# Development and approval of COVID-19 vaccines
# Forbairt agus ceadúnaíocht vacsaíní COVID-19
# COVID-19 vaccines are developed following the same legal requirements for quality, safety and efficacy as for all other vaccines.
# Déantar vacsaíní COVID-19 a fhorbairt de réir na riachtanas dliúcha a bhaineann le caighdeán, sábháilteacht agus éifeachtacht chomh maith le gach vacsaín eile.
# Like all vaccines, the effects of COVID-19 vaccines are tested first in the laboratory, including in animals, and then in human volunteers.
# Mar aon le gach vacsaín, déantar iniúchadh ar thionchair vacsaíní COVID-19 den chéad uair sa laibharlann, lena n-áirítear ar ainmhithe, agus ansin i dtaispeántais daonra.
# (EMA) evaluates COVID-19 vaccines against the same high standards as for all other vaccines before they can be released for use.
# Déanann EMA measúnú ar vacsaíní COVID-19 de réir na caighdeáin ard céanna agus atá ann do gach vacsaín eile sula bhféadfar iad a scaoileadh chun úsáid.
# What is different for COVID-19 vaccines is that development and approval are happening much faster, in response to the public-health emergency caused by the virus.
# Tá difríocht ann maidir le vacsaíní COVID-19 mar go bhfuil forbairt agus ceadú a tharlaíonn go mór níos tapúla, mar fhreagra ar an éigeandáil sláinte poiblí a chruthaigh an víreas.
# EMA evaluates high-quality applications from companies developing COVID-19 vaccines in the shortest time possible, while ensuring its decisions remain robust.
# Déanann EMA measúnú ar iarratais ardchaighdeáin ó chuideachtaí atá ag forbairt vacsaíní COVID-19 chomh tapa agus is féidir, ag cinntiú go bhfanann a chinntí láidir.
# It does this by:
# Déanann sé sin trí:
# providing guidance to help developers of COVID-19 vaccines prepare to apply for approval;
# tabhairt treorach chun cuidiú le forbairtóirí vacsaíní COVID-19 ullmhú chun iarratas ar cheadúnas a dhéanamh;
# using rapid review procedures;
# ag baint úsáide as nósanna athbhreithnithe tapa;
# assessing key data on COVID-19 vaccines as soon as they become available.
# ag an-príomhshonraí a mheas ar vacsaíní COVID-19 chomh luath agus a bheith ar fáil.
# Monitoring COVID-19 vaccine safety
# Ag faire ar shábháilteacht vacsaín COVID-19
# The EU continually monitors the safety and effectiveness of COVID-19 vaccines.
# Déanann an AE monatóireacht leanúnach ar shábháilteacht agus éifeachtacht vacsaíní COVID-19.
# EMA monitors side effects to these vaccines, as it does for all vaccines.
# Foláireamhann an t-EMA taobh istigh de na vacsaíní sin, mar a dhéanann sé do gach vacsaín.
# In parallel, the European Centre for Disease Prevention and Control
# Ar an taobh eile, Ionad um Chosc ar Thimpistí Sláinte na hEorpa
# (ECDC) intensively monitors the effectiveness of COVID-19 vaccines.
# (ECDC) Ag monatóireacht intinneach ar éifeachtacht vacsaíní COVID-19.
# This enables the EU to identify and evaluate new information that arises on the benefits and safety of COVID-19 vaccines promptly.
# Léiríonn sé seo don AE aitheantas agus measúnú a dhéanamh ar fhaisnéis nua a thaithníonn maidir le buntáistí agus slándáil vacsaíní COVID-19 go tapa.
# COVID-19 is the disease associated with severe acute respiratory syndrome coronavirus-2 (SARS-CoV-2).
# Is é COVID-19 an galar a bhaineann leis an síndrom respiratóire gasta tromchúiseach a bhaineann leis an gcoróinvíreas-2 (SARS-CoV-2).
# The COVID-19 outbreak that started in late 2019 was declared a pandemic by the World Health Organization (WHO) on 11 March 2020 (1).
# Deimhníodh go raibh pándéim COVID-19 a thosaigh ag deireadh 2019 ag Eagraíocht Dhomhanda Sláinte (WHO) ar an 11 Márta 2020.
# What are the symptoms of COVID-19?
# Cad iad na síntíomaithe de COVID-19?
# COVID-19 varies in severity from having no symptoms at all (being asymptomatic) to having:
# COVID-19 aistritheann i séarachas ó gan aon síntiús a bheith ann (asimptómaíocht) go dtí:
# change or loss of taste and/or smell,
# athrú nó caillteanas blas agus/nó boladh,
# general weakness,
# laghdú ginearálta,
# diarrhoea,
# diorrúthacht
# fatigue,
# tuirse,
# muscle pains
# pian i matáin
# In serious cases, symptoms can include:
# I gcásanna gráve, is féidir go mbeadh na síntiúis seo ann:
# severe lung infection,
# galar croí trom
# sepsis and septic shock – a generalised infection and inflammatory response,
# séipeas agus soc seipticiúil - galar forleathan agus freagairt inflamáideach,
# all of which need specialised medical care and support.
# gach ceann acu ag teastáil cúram leighis speisialaithe agus tacaíocht.
# A patient’s condition can deteriorate rapidly, often during the second week of disease.
# Is féidir le coinníoll an othair dul i léig go tapa, go minic le linn an dara seachtain den ghalair.
# What are the complications of COVID-19?
# Cad iad na deacrachtaí a bhaineann le COVID-19?
# A percentage of those affected by COVID-19 will require hospitalisation, some even requiring intensive care, sometimes for extended periods.
# Beidh cuid den dream a bhfuil tionchar ag COVID-19 orthu ag teastáil ospidéalú, agus beidh roinnt acu fiú ag teastáil cúraim intinne, uaireanta ar feadh tréimhsí fada.
# Hospitalisation rates increase rapidly with age, in particular for those aged 60 years and above, and for those with underlying health conditions.
# Éiríonn rátaí ospidéil agus aois, go háirithe do dhaoine atá 60 bliain d'aois agus os a chionn, agus do dhaoine a bhfuil coinníollacha sláinte bonnacha acu.
# For COVID-19 cases, the risk of dying increases rapidly with age, and is substantially higher than for influenza.
# I gcásanna COVID-19, méadaíonn an riosca bású go tapaidh le haois, agus is mó go mór ná le haghaidh an bhraonain.
# While bats are believed to be the original host of the virus, the virus now spreads from person to person (human-to-human transmission).
# Cé go gcreidtear go bhfuil na luscaí an t-óigheanúil d'fhuil, scaipeann an víreas anois idir daoine (trédhearcadh idir dhaoine).
# It is currently estimated that if preventive measures are not taken, on average one infected person will infect between two and three other people.
# Tá sé le rá faoi láthair go mbainfear amach, más rud é nach ndéantar bearta cosanta, go gcaithfidh duine atá breoite idir dhá agus trí duine eile a mhealladh ar aghaidh.
# The virus is transmitted mainly via respiratory droplets and aerosols when sneezing, coughing, or interacting with others in close proximity (usually less than two metres).
# Déantar an víreas a chur trasna go príomha trí bhrollach anailíseach agus aerosálacha nuair a bhíonn duine ag spraoi, ag casacht nó ag caint le daoine eile i dteannta a chéile (de ghnáth faoi dhá mhéadar).
# The virus can survive on different surfaces for several hours (on copper or cardboard) or up to a few days (on plastic or stainless steel).
# Is féidir leis an víreas maireachtáil ar dhromchláir éagsúla le haghaidh roinnt uaireanta (ar chobre nó cárta cartón) nó suas go dtí cúpla lá (ar phlaisteach nó ar cruach iniox).
# The average incubation period for COVID-19
# An t-am meáchain incubáide don COVID-19
# Who is at risk of COVID-19?
# Cé acu atá i mbaol le COVID-19?
# Everyone is at risk of getting COVID-19, with some population groups having a higher risk of developing severe disease.
# Tá gach duine i mbaol COVID-19 a fháil, le roinnt grúpaí daonra ag baint amach baol níos airde do ghortú tromchúiseach.
# Crowded indoor environments provide opportunities for COVID-19 outbreaks, with prisons, migrant centres and food processing plants being examples of places where outbreaks have been reported.
# Soláthraíonn timpeallachtaí inmheánacha plódaithe deiseanna do thachtaí COVID-19, le príosúin, láraigh dhaonra agus monarchana próiseála bia mar samplaí áiteanna ina bhfuil tuairiscithe de thachtaí.
# Those groups at increased risk of developing severe COVID-19 disease are:
# Is iad na grúpaí sin at bhaint amach atá i mbaol níos mó dul chun cinn galar COVID-19 a fhorbairt:
# people aged 60 years and above;
# daoine atá 60 bliain d'aois agus os a chionn;
# people with underlying health conditions, such as obesity, hypertension, diabetes, cardiovascular disease, chronic respiratory disease, or weakened immune systems.
# daoine a bhfuil coinníollacha sláinte bonnaithe acu, cosúil le otrachas, hipertinsin, diabhéiteas, galar croí-ghleanna, galar duáin fada, nó córais imdhíonachta laghdaithe acu.
# How can COVID-19 be prevented?
# Conas is féidir le COVID-19 a chosc?
# Vaccines to prevent COVID-19 first became available in the EU/EEA in late December 2020.
# Tháinig vacsaíní chun cosanta a chur i bhfeidhm in aghaidh COVID-19 don chéad uair san Aontas Eorpach/ÁEE i ndeireadh Mí na Nollag 2020.
# It is recommended to keep physical distance (a minimum of one or, ideally, two metres) from others in public places, and to avoid gatherings of large groups of people to reduce the risk of infection through respiratory droplets.
# Moltaítear do dhaoine fanacht ar shiúl ó dhaoine eile i bpobail (ar a laghad méadar amháin nó, más féidir, dhá mhéadar) agus searmanais mhóra daoine a sheachaint chun an riosca a laghdú de ghalar a fháil trí dhroicheadacha an aeir a laghdú.
# For an overview of actions that people and communities can take to help slow down the spread of COVID-19 see: Infographic: Non-pharmaceutical measures.
# Chun breathnú ar na gníomhartha is féidir le daoine agus pobail a glacadh chun cuidiú leis an dul chun cinn a mhoilliú ar leathadh COVID-19, féach: Infographic: Míreanna neamhfharmaceolaíocha.
# The virus enters the body via the eyes, nose or mouth, so it is important to avoid touching the face with unwashed hands.
# Teann an víreas isteach sa chorp trína suíl, srón nó béal, mar sin tá sé tábhachtach a chinntiú nach mbuailtear leis an aghaidh le lámha neamhghlan.
# Scientists and clinicians are studying several treatments for COVID-19.
# Tá taighdeoirí agus cliniciúirí ag staidéar ar roinnt cóireálacha do COVID-19.
# Healthcare providers mostly treat COVID-19 symptoms rather than targeting the virus itself by offering supportive care
# Is é an chuid is mó de lucht soláthair cóireála sláinte agus tacaíocht a thairiscint do chomharthóirí COVID-19 seachas díriú ar an víreas féin.
# For severely and critically ill patients, a number of medicines are being tested to target the virus, but their use still needs to be assessed more thoroughly.
# Tá roinnt drugaí á bpróiseáil chun an víreas a dhréachtú do ghalar go trom agus go criticiúil, ach tá sé fós ag teastáil breis measúnú a dhéanamh ar a n-úsáid.
# For the latest information on COVID-19 treatments, visit the European Medicines Agency’s (EMA) website: Treatments and vaccines for COVID-19
# Chun an t-eolas is déanaí faoi chóireáil COVID-19 a fháil, tabhair cuairt ar láithreán gréasáin Ghníomhaireacht na bhEorpa (EMA): Cóireálacha agus vacsaíní do COVID-19.
# After your Comirnaty (Pfizer/ BioNTech) COVID-19 vaccine
# Tar éis do vacsaín COVID-19 Comirnaty (Pfizer/BioNTech)
# Do read the COVID-19 vaccine information leaflet we gave you about the vaccine too.
# Léigh an leathfhoclach eolais faoi vacsaín COVID-19 a thugamar duit faoin vacsaín freisin.
# have tenderness and swelling in the arm where they had the vaccine injection
# Tá teannas agus uathachas sa lámh ina raibh an tóga vacsaíní.
# have diarrhoea
# tá leatracán orm
# As with all vaccines, you can report suspected side effects to the Health Products Regulatory Authority (HPRA).
# Mar a bhaineann sé le gach vacsaín, is féidir leat tuairimí aitheanta a chur in iúl don Údarás Rialála Táirgí Sláinte (HPRA).
# To report side effects to a COVID-19 vaccine, please visit www.hpra.ie/report
# Chun tuairisc a dhéanamh ar taobhghéarrthuithe a bhaineann le vacsaín COVID-19, téigh chuig www.hpra.ie/report
# What if I have a fever or have aches and pains?
# Cad é dá mbeadh fiabhras orm nó má bheadh pian agus tinneas orm?
# If you have a fever or you have aches and pains, you can take paracetamol or ibuprofen to help.
# Má tá fiabhras ort nó má tá pian agus pléisiúr ort, is féidir leat paracéitéamol nó ibiopróifín a ghlacadh chun cuidiú.
# Do not take ibuprofen if you are pregnant.
# Ná glac ibuprofen má tá tú ag súil leanbh.
# Do I need to do anything before I get the second dose of the vaccine?
# An gá dom aon rud a dhéanamh sula ghlacaim leis an dara dósa den vacsaín?
# When you are having your next and final dose of the vaccine, please tell the vaccination team if there have been any changes in your medical history.
# Nuair atá tú ag glacadh do dhóis dheiridh den vacsaín, abair le foireann na vacsaínithe más rud éigin tar éis athruithe a tharla i d'eachtraí leighis.
# Bring your vaccination record card with you when going to get the second dose.
# Tóg do chárta taifead vacsaín leat nuair a thugann tú don dara dhaingniú.
# This will be in 28 days’ time (four weeks).
# Beidh sé sin ar siúl i gceithre seachtaine (28 lá) amach anseo.
# The good news
# An nuacht maith
# Getting a COVID-19 vaccine should protect you from the serious complications of COVID-19.
# Ba chóir go mbeadh tú sábháilte ó na comharthaí tromchúiseacha de COVID-19 tar éis duit vacsaín COVID-19 a fháil.
# It is much safer for your immune system to learn this through vaccination than by getting COVID-19.
# Is é an bhealach is sábháilte ná a fhoghlaim trí vacsaíní a fháil ar do chóras imdhíonach ná trí COVID-19 a fháil.
# It takes 7 days after getting the second dose for it to work.
# Glacann sé 7 lá tar éis an dara dhaingniú leis ag obair.
# There is a small chance you might still get COVID-19 even if you have the vaccine.
# Is féidir go mbeadh deis beag ann go fóill go mbeadh COVID-19 ort fiú má tá an vacsaín agat.
# follow social distancing guidelines (keep two metres apart from others where possible)
# lean ar threoirí scaradh sóisialta (coinneáil dhá mhéadar ar leith ó dhaoine eile más féidir)
# Have a question?
# An bhfuil ceist agat?
# If you are unsure about anything, or have any questions about the COVID-19 vaccine please ask your vaccinator today.
# Má tá aon amhras ort faoi rud ar bith, nó má tá aon cheist agat faoi vacsaín COVID-19, iarr ar do vacsaíneoir inniu.
# After your COVID-19 Vaccine Moderna
# Tar éis do Vacsaín COVID-19 Moderna
# have tenderness, swelling, redness and/or itching in the arm where they had the vaccine injection
# bíonn tocht, bolgadh, deargadh agus/nó an fhearg ag duine sa lámh ina ndearna siad an t-instealladh vacsaín
# have swollen lymph glands under the arm where they had the injection
# Tá na nódanna lymphoideacha faoi bhoilg faoi na cosa inar cuireadh an t-instealladh orthu.
# have nausea or vomiting
# taithíonn tinneas cinn nó éagoir orm
# Bring your vaccination record card with you when going to get the second dose
# Tóg do chárta taifead vacsaínithe leat nuair a théann tú chun an dara dóis a fháil.
# Getting a COVID-19 vaccine should protect you from the serious complications of COVID-19.
# Ba chóir go mbeadh tú cosanta agus tú ag glacadh le vacsaín COVID-19 ó chiontuithe casta COVID-19.
# It takes 14 days after getting the second dose for it to work.
# Tógann sé 14 lá tar éis an dara dóis chun é a bheith ag obair.
# follow social distancing guidelines (keep two metres apart from others where possible)
# lean ar threoirí scaradh sóisialta (coinneáil dhá mhéadar ar a laghad idir thú féin agus daoine eile más féidir)
# wear a face covering
# caith masgara aghaidh
# wash your hands regularly.
# Nigh do lámha go rialta.
# evaluate_OpenAI-enga-baseline.ipynb  pred.txt  src-test.txt  tgt-test.txt

# %%
# !pip3 install sacrebleu[ja]
# Out:
# Collecting sacrebleu[ja]
#   Downloading sacrebleu-2.4.1-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 2.7 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu[ja])
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ja]) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ja]) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ja]) (1.25.2)
# Collecting colorama (from sacrebleu[ja])
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ja]) (4.9.4)
# Collecting mecab-python3<=1.0.6,>=1.0.5 (from sacrebleu[ja])
#   Downloading mecab_python3-1.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (581 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.6/581.6 kB 26.5 MB/s eta 0:00:00
# Collecting ipadic<2.0,>=1.0 (from sacrebleu[ja])
#   Downloading ipadic-1.0.0.tar.gz (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 70.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ipadic
#   Building wheel for ipadic (setup.py) ... done
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556704 sha256=800fd050510ba05b657423bf5a081802e3d9a538e8f30c796d7b6d87445fc438
#   Stored in directory: /root/.cache/pip/wheels/5b/ea/e3/2f6e0860a327daba3b030853fce4483ed37468bbf1101c59c3
# Successfully built ipadic
# Installing collected packages: mecab-python3, ipadic, portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 ipadic-1.0.0 mecab-python3-1.0.6 portalocker-2.8.2 sacrebleu-2.4.1

# %%
# to access sacrebleu help:
# !sacrebleu --help
# sentence level blue is too noisy. Uncomment if needed.
# !sacrebleu tgt-test.txt < pred.txt -m bleu -sl | tee -a experiment_log.txt
# !echo -e "+++ Evaluation Results for gpt-3.5-turbo-0125 ENGA Baseline +++ \n" | tee -a experiment_log.txt
# !echo "++ using sacrebleu ++" | tee -a experiment_log.txt

# !sacrebleu tgt-test.txt < pred.txt -m bleu --force | tee -a experiment_log.txt
# !sacrebleu tgt-test.txt < pred.txt -m bleu -lc --force \
  | tee -a experiment_log.txt

# !sacrebleu tgt-test.txt < pred.txt -m ter --force | tee -a experiment_log.txt
# !sacrebleu tgt-test.txt < pred.txt -m chrf --chrf-beta 1 --force \
| tee -a experiment_log.txt
# !sacrebleu tgt-test.txt < pred.txt -m chrf --chrf-beta 3 --force \
  | tee -a experiment_log.txt
# Out:
# +++ Evaluation Results for gpt-3.5-turbo-0125 ENGA Baseline +++
#
# ++ using sacrebleu ++
# {
#  "name": "BLEU",
#  "score": 19.7,
#  "signature": "nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1",
#  "verbose_score": "51.9/25.0/14.0/8.5 (BP = 0.993 ratio = 0.993 hyp_len = 6532 ref_len = 6577)",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.4.1"
# }
# {
#  "name": "BLEU",
#  "score": 20.0,
#  "signature": "nrefs:1|case:lc|eff:no|tok:13a|smooth:exp|version:2.4.1",
#  "verbose_score": "52.6/25.3/14.2/8.6 (BP = 0.993 ratio = 0.993 hyp_len = 6532 ref_len = 6577)",
#  "nrefs": "1",
#  "case": "lc",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.4.1"
# }
# {
#  "name": "TER",
#  "score": 71.2,
#  "signature": "nrefs:1|case:lc|tok:tercom|norm:no|punct:yes|asian:no|version:2.4.1",
#  "nrefs": "1",
#  "case": "lc",
#  "tok": "tercom",
#  "norm": "no",
#  "punct": "yes",
#  "asian": "no",
#  "version": "2.4.1"
# }
# {
#  "name": "chrF1",
#  "score": 48.0,
#  "signature": "nrefs:1|case:mixed|eff:yes|nc:6|nw:0|space:no|version:2.4.1",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "yes",
#  "nc": "6",
#  "nw": "0",
#  "space": "no",
#  "version": "2.4.1"
# }
# {
#  "name": "chrF3",
#  "score": 47.5,
#  "signature": "nrefs:1|case:mixed|eff:yes|nc:6|nw:0|space:no|version:2.4.1",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "yes",
#  "nc": "6",
#  "nw": "0",
#  "space": "no",
#  "version": "2.4.1"
# }
