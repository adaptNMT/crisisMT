# %%
#@markdown ### Directory for results and models:
results_dir = "exp/crisismt/openai/enmr/baseline" #@param {type:"string"}

from google.colab import drive
drive.mount('/content/drive')
HOME='/content/drive/MyDrive'
# Out:
# Mounted at /content/drive

# %%
HOME='/content/drive/MyDrive'

# %%
# %cd $HOME/$results_dir
# Out:
# /content/drive/MyDrive/exp/crisismt/openai/enmr/baseline

# %%
# !pip install --upgrade openai
# Out:
# Collecting openai
#   Downloading openai-1.14.3-py3-none-any.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.6.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.5 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.14.3

# %%
import os
import openai

os.environ["OPENAI_API_KEY"] = "sk-..."
openai.api_key = os.environ["OPENAI_API_KEY"]

# %%
from openai import OpenAI
client = OpenAI()

# %%
# gpt-3.5-turbo (oringally - now swapped in my custom model)
# open the test file for reading, src-test.txt
# open the pred file for writing, pred.txt
src= open('src-test.txt', 'r')
pred = open('pred.txt', 'w')

Lines = src.readlines()
count = 0
# Strips the newline character
for line in Lines:
    count += 1
    srcl=line.strip()
    print(srcl)

    completion = client.chat.completions.create(
        model="gpt-3.5-turbo-0125",
        messages=[{"role": "system", "content": "Translate English to Marathi."},
                  {"role": "user", "content": srcl}],
        temperature=0.5
    )

    translated_text = completion.choices[0].message.content
    print(translated_text) # display translations in real time
    pred.writelines(translated_text + '\n')

src.close()
pred.close()
# !ls
# Out:
# Chief Minister Uddhav Thackeray has announced lockdown-like rules across the state to prevent corona infection.
# मुख्यमंत्री उद्धव ठाकरे यांनी कोरोना संक्रमणाची टाळणीसाठी राज्यभरात लॉकडाऊन-सारख्या नियमांची घोषणा केली आहे.
# No party is an exception.
# कोणत्याही पक्षाला विशेषांतर नाही.
# Like big cities like Mumbai, Pune, Nashik, all other districts are suffering from this.
# मुंबई, पुणे, नाशिक यांच्यांसारख्या मोठ्या शहरांमध्ये इतर सर्व जिल्ह्यांनी ह्याची त्रास भोगत आहेत.
# In this era of corona, the issues of development, health and healthcare are being discussed instead of personal criticism.
# कोरोना युगात, व्यक्तिगत आलोचना व्यापाराच्या बदलाच्या ठिकाणी विकास, आरोग्य आणि आरोग्य सेवा यांच्या मुद्द्यांवर चर्चा होत आहे.
# He has never set up watermelon-melon society.
# त्याने कधीही तरबूज-कलिंगी सोसायटी स्थापित केली नाही.
# He said, 'Ajit Anantrao Pawar is up and Chandrakant Patil is Champa.
# त्याने म्हणाले, 'अजित अनंतराव पवार उठले आणि चंद्रकांत पाटील चंपा आहेत.'
# Stop calling me Champa, otherwise I will also tell the short forms of Parth Pawar and others, he replied.
# माझ्यावर चंपा म्हणून बोलणं थांबवा, अथवा मी पर्थ पवार आणि इतरांच्या संक्षिप्त नावांची म्हणूनही सांगू शकतो, तो म्हणाला.
# But thousands of people are attending the campaign.
# पण हजारो लोक कॅम्पेनमध्ये उपस्थित आहेत.
# He said, 'Once the polls are over, the situation in Pandharpur will come to the fore.
# त्याने म्हणाले, 'निवडणूक संपल्यावर पंढरपूरमध्ये जागतिक स्थिती सामन्यात येईल.'
# On the one hand, the state had banned political and cultural events due to corona, which had attracted such a large crowd for these events.
# एकहीतरी, राज्याने कोरोनामुळे राजकीय आणि सांस्कृतिक कार्यक्रमांची प्रतिबंधित केली होती, ज्यामुळे या कार्यक्रमांसाठी एकाच ठिकाणी इतरांची भरपूर भीड आली होती.
# But the next day the same situation happened again.
# पण उद्या पुन्हा त्याची स्थिती घडली.
# On the other hand, the Deputy Chief Minister's program showed a basket case of government rules.
# तरीही, उपमुख्यमंत्रीच्या कार्यक्रमात सरकारच्या नियमांचे एक बेस्केट केस दाखवले.
# Ranjit Singh Mohite Patil, who participated in the BJP's campaign rally, also contracted corona.
# रंजीत सिंह मोहिते पाटील, ज्याने भाजपच्या चुनावी रैलीत सहभाग घेतला होता, त्याने कोरोना लागला.
# But the campaign rallies here are very crowded, people don't wear masks, there is no sanitizer system.
# पण येथील प्रचार सभें अत्यंत भीडगार आहेत, लोक मास्क घातला नाही, सॅनिटायझर प्रणाली नाही.
# Therefore, this by-election is being held, but at present, the rules regarding corona are being violated here.
# तसंच, ह्या पुनरावृत्तीचा निवडणूक घेतला जात आहे, पण वर्तमानत कोरोना विषयीच्या नियमांची अवहेलना येथे आहे.
# If they are not followed, local Election Commission officials are filing cases against the organizers, Waghmare told BBC Marathi.
# त्यांनी स्थानिक निवडणूक आयोगाच्या अधिकाऱ्यांवर केस दाखल करण्याचा प्रस्ताव न असल्यास, वाघमारे बीबीसी मराठीला सांगितलं.
# Medical Education Minister Amit Deshmukh tweeted about it.
# मेडिकल शिक्षण मंत्री अमित देशमुख यांनी हे ट्विट केलं.
# After that, the demand for postponing the examination of medical courses was also emphasized.
# त्यानंतर, वैद्यकीय पाठ्यक्रमांच्या परीक्षेची टाळण्याची मागणीही वेगवेगळीत दाखवली गेली.
# It will be a lockdown for the next 15 days from 8pm on April 14th.
# अप्रैल १४ रोजी संध्याकाळी ८ वाजता पाचरा १५ दिवसांसाठी लॉकडाऊन असेल.
# The university had said that the exams would be held with all the necessary precautions related to covid.
# विद्यापीठाने सांगितलं होतं की कोविडसंबंधित सर्व आवश्यक सावधानींसह परीक्षा घेतल्या जातील.
# It has been observed that many students do not test for corona despite having symptoms to sit for the exam.
# काही विद्यार्थ्यांना परीक्षेत उपस्थित असण्याच्या लक्षणांसह कोरोना चाचणी करण्याची गरज असूनही त्यांची चाचणी करण्याची प्रवृत्ती किंवा अभाव दिसत आहे.
# It is doubtful whether the means of travel will be available to them during the lockdown in the state.
# राज्यातील लॉकडाउन काळात त्यांना प्रवासाचे साधन उपलब्ध असेल हे संदेहास्पद आहे.
# These students will have to use the mess, washroom.
# ह्या विद्यार्थ्यांना खाण्याचे ठिकाण, शौचालय वापरायला लागेल.
# It will be a lockdown until the end of April.
# एप्रिलच्या शेवटच्या पर्यंत लॉकडाऊन असेल.
# The Chief Minister convened a meeting of all party leaders.
# मुख्यमंत्रीने सर्व पक्षांच्या नेत्यांची एक बैठक आयोजित केली.
# However, as the number of corona patients is not decreasing, a prolonged lockdown has been imposed.
# पण कोरोना रुग्णांची संख्या कमी होत नाही, त्यामुळे लंबिचं लॉकडाऊन लागू केलं आहे.
# However, the weekend lockdown was imposed as the number of corona patients was not declining.
# पण, कोरोना रुग्णांची संख्या कमी होत नसल्यामुळे आठवड्यातील आठवड्यात लॉकडाऊन लागू केला गेला.
# Restrictions will be imposed after the elections in Pandharpur.
# निवडणुकानंतर पंढरपूरमध्ये प्रतिबंध लागू केले जातील.
# The same restrictions apply to hotels and restaurants.
# हॉटेल्स आणि रेस्टॉरंट्सवरही त्यांच्यावर एकसारख्या प्रतिबंधांचा अनुपालन केला जातो.
# Cold storage and warehouses will be open.
# कोल्ड स्टोरेज आणि गोदाम सुरू राहील.
# Import-export mechanism.
# आयात-निर्यात व्यवस्था.
# Vehicles transporting ATMs, postal services, ports, licensed drugs and pharma products
# एटीएम्स, डाक सेवा, बंदरगाह, परवानगी असलेली औषधे आणि फार्मा उत्पादने परिवहन करणारी वाहने
# This facility will be provided to seven crore citizens.
# ह्या सुविधा सात कोटी नागरिकांना पुरवण्यात येणार आहे.
# 1500 to the official five lakh peddlers.
# १५०० ते आधिकारिक पाच लाख विक्रेते.
# Prices ranged from ten to five.
# किंमतेचा वेगवेगळ्या असतात पाच ते दहा.
# People associated with the newspaper should be vaccinated as soon as possible.
# अखबारात काम करणारे लोक त्वरितपणे लस लावणे आवश्यक आहे.
# Amusement parks, arcades, video game parlors will be closed.
# आटोपार्क, आर्केड, व्हिडिओ गेम पार्लर संपूर्ण बंद ठेवले जातील.
# Discount will be given for 10th-12th class students.
# 10 वी - 12 वी विद्यार्थ्यांसाठी सवलत दिली जाईल.
# The state government has issued these orders under Break the Chain.
# राज्य सरकारने त्यांच्या निर्देशांची अंतर्गत ती आदेश जारी केली आहेत.
# These orders have been given in the new regulations issued by the state government under 'Back the Chain'.
# नवीन नियमावलीत 'बॅक द चेन' अंतर्गत राज्य सरकारद्वारे जारी केलेल्या आदेशांमध्ये दिलेले आहेत.
# The order also said that detailed information about the train should be given to the authority.
# आदेशानुसार, प्रशासनाला ट्रेनच्या तपशीलांची माहिती प्रदान केली पाहिजे.
# The state government's order also directed the railways to arrange rapid antigen testing at railway stations for such passengers.
# राज्य सरकारचे आदेश रेल्वे संचालनाला त्या यात्र्यांसाठी रेल्वे स्थानकांवर रॅपिड एंटिजन चाचणी आयोजित करण्याचे दिशा दिले.
# Leader of Opposition in the Assembly Devendra Fadnavis has replied to him.
# विधानसभेतील विरोधातील नेते देवेंद्र फडणवीस त्यांनी त्यांना प्रत्युत्तर दिलं आहे.
# The director of the company was taken to the police station only after the opposition appealed and fabricated a 'story'.
# कंपनीच्या निदेशकाला विरोधकांनी आपत्ती केल्यानंतर फक्त 'कथा' उत्पन्न केल्यानंतर पोलीस ठाण्यात घेतले गेले.
# We are not afraid to file charges.
# आम्हाला शिकायत करण्याचा भीती नाही.
# As the situation of Corona in Maharashtra has spiraled out of control, attempts are being made to shift everything to the Central Government.
# महाराष्ट्रातील कोरोना स्थिती त्रासाकारक रुपात वाढत असताना, सर्व काही केंद्र सरकारला हस्तक्षेपणे करण्याचा प्रयत्न केला जात आहे.
# At the same time, the total number of active corona patients in the state has reached 6 lakh 70 thousand 388.
# त्याचा वेळेला, राज्यातील सक्रिय कोरोना रुग्णांची कुल संख्या 6 लाख 70 हजार 388 परंतु पोहोचली आहे.
# In the last 24 hours, 68 thousand 631 new patients have been diagnosed in the state.
# मागील 24 तासांत 68 हजार 631 नवीन रुग्णांची डायग्नोसिस झाली आहे राज्यात.
# Yesterday the number was 419.
# काल आंकडा ४१९ होता.
# Pune district has the highest number of 1 lakh 22 thousand 486 patients.
# पुणे जिल्ह्यात 1 लाख 22 हजार 486 रुग्ण आहेत.
# In Aurangabad it is 14 thousand 344, in Jalgaon it is 12 thousand 795 and in Nanded it is 12 thousand 576.
# औरंगाबादमध्ये १४ हजार ३४४, जळगावमध्ये १२ हजार ७९५ आणि नांदेडमध्ये १२ हजार ५७६ आहेत.
# Home Minister Dilip Walse-Patil gave hints to
# होम मंत्री दिलीप वालसे-पाटीलने सूचना दिली.
# At present 36 lakh 75 thousand 518 persons are in home quarantine in the state.
# सध्या राज्यात ३६ लाख ७५ हजार ५१८ व्यक्ती घरी आत्मविश्रांतीत आहेत.
# BJP leaders, including Leader of Opposition Devendra Fadnavis, reached Thane police station on Saturday night after the Mumbai police arrested the director of a pharmaceutical company for questioning.
# बीजेपीचे नेते, सहाय्यक विरोधी नेते देवेंद्र फडणवीस समाविष्ट असून, शनिवार रात्री मुंबई पोलिसांनी एक फार्मास्युटिकल कंपनीच्या निदेशकाचा प्रश्नार्थात अटक केल्यानंतर थाणे पोलिस ठाण्यात जाहिर झाले.
# One of them is a NCP activist.
# त्यांमध्ये एक NCP कार्यकर्ता आहे.
# The injections were being sold on the black market for Rs 30,000 to Rs 35,000.
# त्या इंजेक्शन ब्लॅक मार्केटवर रु. ३०,००० ते रु. ३५,००० वर विकल्या जात होत्या.
# Of these, Dilip Gaikwad is a NCP activist from Baramati.
# यापैकी, दिलीप गायकवाड बारामतीतून NCP चे कार्यकर्ता आहे.
# Putting pressure on the police is considered as interference in government work.
# पोलिसांवर दाब टाकणे सरकारच्या कामात हस्तक्षेप करण्याचे मान्य ठरते.
# Manish Singh, technical director of Brook Pharma Company, and his accomplice Varun Kundra, a resident of Daman, were arrested by Valsad police on April 15 on charges of blackmailing a remedicivir injection.
# ब्रूक फार्मा कंपनीचे तांत्रिक निदेशक मनीष सिंह आणि त्यांचे सहाय्यक वरुण कुंद्रा, डामणच्या निवासी, दावेदार्यांच्या विरुद्ध वलसाड पोलीसांनी 15 एप्रिलला रेमेडिसिव्हिर इंजेक्शनची धमकी देण्याच्या आरोपात अटक केली.
# Manmohan Singh has sent a letter to Prime Minister Narendra Modi.
# मनमोहन सिंग ने पंतप्रधान नरेंद्र मोदीला एक पत्र पाठविला आहे.
# With the right strategy, we can work much better and faster.
# सही योजनेने, आम्ही खूप चांगल्या व जलद काम करू शकतो.
# In this regard, Manmohan Singh suggested that states should be allowed to decide on immunization of frontline employees even if they are below 45 years of age.
# या संदर्भात, मनमोहन सिंग यांनी सुचवलं की राज्यांना आधीच्या ४५ वर्षांपेक्षा कमी वयाच्या फ्रंटलाइन कर्मचाऱ्यांच्या सूरक्षणाच्या विचारावर निर्णय करायला परवानगी द्यावी.
# The former prime minister also suggested that the government should clarify how the vaccines are supplied to the states.
# माजी पंतप्रधानही सुचवले की सरकारने प्रदेशांना लसीकरण कसे पुरविले ते स्पष्ट करावे लागेल.
# He suggested that the central government reserve 10 per cent of the vaccine for emergency use.
# त्यांनी सूचित केलं की केंद्र सरकारने आपत्कालीन वापरासाठी टीका 10 प्रतिशत आरक्षित करावं.
# Therefore, the focus should be on what percentage of the total population was vaccinated, not on the total number of vaccinated citizens, Manmohan Singh said.
# मनमोहन सिंग्ह यांनी म्हणाले की, त्यामुळे पूर्ण जनसंख्येतून किती टक्के लोकांनी लसीकरण केले हे लक्षात ठेवण्याची गरज आहे, लसीकरण केलेल्या सर्व नागरिकांच्या पूर्ण संख्येवर नाही.
# This can increase vaccine production.
# ह्यामध्ये टीका उत्पादन वाढवू शकतो.
# Similarly, its response will show whether the government is serious about preventing corona.   - Dr. Manmohan Singh, former Prime Minister
# तसंच त्याची प्रतिसाद दर्शवणार की सरकार कोरोना रोखण्याच्या गंभीर आहे का हे दाखवेल. - डॉ. मनमोहन सिंग, माजी पंतप्रधान
# We must be ready to face it.
# आपल्याला त्याचा सामना करण्यास तयार असावं लागेल.
# Other variants followed, making the situation even more difficult.
# इतर प्रकारांची उत्पत्ती झाली, ज्यामुळे परिस्थिती आणखी कठीण होत गेली.
# The RBI had not changed interest rates last week.
# मागील आठवड्यात आरबीआयने व्याज दरांमध्ये कोणतेही बदल केले नाहीत.
# So many states have imposed restrictions.
# अनेक राज्यांनी प्रतिबंध लागू केले आहेत.
# The government can also announce a financial plan if needed, he added.
# त्याने जर आवश्यक असेल तर सरकारही एक आर्थिक योजना जाहीर करू शकते, असं तो उक्त केलं.
# However, private hospitals are increasing the cost of treatment of corona patients, citing shortage of oxygen, shortage of remedicivir and other reasons for treatment.
# परंतु, खाजगी रुग्णालयांनी कोरोना रुग्णांच्या उपचाराची खर्च वाढविण्याचा कारण ऑक्सिजनची कमतरता, रेमेडिविरची कमतरता आणि उपचाराच्या इतर कारणे देत आहेत.
# However, in some of these hospitals, financial robbery of patients is going on.
# पण काही या रुग्णालयांमध्ये रुग्णांच्या आर्थिक लूटपाटीची घटना चालू आहे.
# Private hospitals in the district are being charged Rs 4,000 for general beds and Rs 8,000 for oxygen beds.
# जिल्ह्यातील खासगी रुग्णालयांना सामान्य बेड्ससाठी ४,००० रुपये आणि ऑक्सिजन बेड्ससाठी ८,००० रुपये वसूलले जात आहेत.
# Attempts are also being made to put pressure on patients by asking them to relocate after being asked about increased payments.
# रुग्णांना मोठ्या देयांच्या विचारात विचारल्यानंतर त्यांना पुनर्वास करण्याच्या विचारात दबाव टाकण्याच्या प्रयत्नांचा समर्थन केला जात आहे.
# Therefore, the relatives of the patients are alleging that the district administration is conveniently ignoring such matters as the district administration has to take the help of private hospitals.
# तसंच, रुग्णांच्या निकटस्थांची आरोपीत आहेत की जिल्हा प्रशासन त्या प्रकारच्या विषयांच्या लक्षात घेत आहे कारण जिल्हा प्रशासनाने खाजगी रुग्णालयांची मदत घेणे आवश्यक आहे.
# This has led to the proliferation of private hospitals.
# हे खासगी रुग्णालयांच्या विस्ताराला नेलं आहे.
# Also, if found guilty in this case or violation of government rules, action will be taken against those concerned.
# ही घटना अथवा सरकारच्या नियमांचा उल्लंघन करण्याच्या दृष्टीने दोषी ठरल्यास, संबंधित व्यक्त्यांवर कारवाई केली जाईल.
# Amravati, like other cities in the state, still has strict restrictions.
# अमरावती, राज्यातील इतर शहरांच्या प्रमाणातही कडक रोकटे आहेत.
# Initially, the rising mortality rate and the growing number of coronaries have created a scary atmosphere.
# सुरूवातीला, मृत्युदर वाढत असल्याचे आणि कोरोनाच्या संख्येची वाढ होत असल्याचे भयानक वातावरण तयार केले आहे.
# On the other hand, as the number of tests decreased, so did the number of patients.
# तरीही, जर परीक्षणांची संख्या कमी होत तर पेटीशंट्सची संख्या कमी होते.
# Amravati district became the 'hotspot' of Kovid-19, surpassing Mumbai, Pune and Nagpur.
# अमरावती जिल्ह्याला कोविड-१९च्या 'हॉटस्पॉट' म्हणून नागपूर, मुंबई आणि पुणे पार करण्यात आलं.
# Wedding ceremonies, other public places were crowded.
# लग्न समारंभ, इतर सार्वजनिक स्थळांत भीड भरपूर होती.
# During this lockout only essential services were started.
# या लॉकआउट काळात केवळ आवश्यक सेवा सुरू केली होती.
# Other districts also saw a large increase in the number of coronary addicts.
# इतर जिल्ह्यांमध्ये पन ज्यात दीर्घकाळाचे व्यसनी वाढ होते.
# After a month, between March 22 and 30, the number of patients had come down to 2,981.
# एक महिन्यानंतर, मार्च २२ ते ३० यांच्या दरम्यान, रुग्णांची संख्या २,९८१ पर्यंत कमी झाली होती.
# During the intervening period, patients were shifted to Amravati due to insufficient number of beds for coroners in Nagpur and some other districts.
# त्या अंतरालात, नागपूर आणि काही इतर जिल्ह्यांमध्ये कोरोनाच्या मृत्यूच्या वाटचालीसाठी पर्याप्त बेड्सची कमी असल्यामुळे रुग्णांना अमरावतीत व्यवस्थित केले गेले.
# Due to strict restrictions and response from the people, the situation in Amravati district is now normal.
# कठोर प्रतिबंध आणि लोकांच्या प्रतिसादामुळे अमरावती जिल्ह्यातील स्थिती आता सामान्य झाली आहे.
# n the last 24 hours, 519 patients have died due to corona in the state, according to figures released by the health department.
# आखेरी २४ तासांत ५१९ रुग्णांच्या कोरोना कारणाने मृत्यू झाले असून, आरोग्य विभागाने जाहिर केलेल्या तपशीलांनुसार हे माहिती आहे.
# Therefore, the recovery rate is expected to increase.
# तसं कारण रिकव्हरी दर वाढण्याची अपेक्षा आहे.
# Today, the number has finally reached 3 lakh 76 thousand 962.
# आज, आकडा अंतिमतः 3 लाख 76 हजार 962 पर्यंत पोहोचला आहे.
# State Health Minister Rajesh Tope has appealed not to remove the pain on the body.
# राज्य आरोग्य मंत्री राजेश टोपे यांनी शरीरावरील दुखाचा काढायला अपील केली आहे.
# Even if you find some symptoms, get tested.
# काही लक्षण सापडल्यास तपासणी करा.
# The vaccine will play an important role in keeping the corona epidemic safe
# कोरोना महामारी सुरक्षित ठेवण्यात लस एक महत्वाची भूमिका बजावेल.
# They must be obeyed.
# त्यांना पालन केले पाहिजे.
# The decision to postpone the 10th and 12th standard examinations was recently announced by the school education minister Varsha Gaikwad.
# शाळा शिक्षण मंत्री वर्षा गायकवाड ने अखेर दहावी आणि बारावी चाचण्यांची टाळणी करण्याचा निर्णय घेण्याची सुचना दिली.
# How these students can be assessed by studying through the school education department, what are the guidelines of the central government will be considered and its decision will be announced.
# या विद्यार्थ्यांना शाळा शिक्षण विभागाद्वारे मूल्यांकन कसा केला जाऊ शकतो, केंद्र सरकारच्या मार्गदर्शिका कोणत्या प्रमाणात लागू केल्या जातील आणि त्याचा निर्णय घोषित केला जाईल.
# Against this backdrop, what about the Maharashtra Board's 10th and 12th examinations?
# या परिस्थितीवर कशी आहे, महाराष्ट्र बोर्डच्या १० वी आणि १२ वीच्या परीक्षांबद्दल काय सांगायचं?
# This information was given by Aslam Sheikh while talking to reporters after the meeting of the state cabinet
# ह्या माहितीची बातमी राज्य कॅबिनेटच्या बैठकानंतर पत्रकारांशी बोलताना अस्लम शेख यांनी दिली.
# Despite the restrictions, vehicles are moving on the road.
# प्रतिबंधांच्या विरोधात, वाहन रस्त्यावर चालत आहेत.
# Meanwhile, Aslam Sheikh also hinted that public transport would not be completely shut down, adding that care would be taken to ensure that people would not have much difficulty in traveling.
# तथापि, अस्लम शेखने यातायातावरील पूर्ण बंदीचा सूचना दिला नाही, त्यामुळे सुनिश्चित केलं की लोकांना प्रवासात किती कठीणता येणार नाही त्याची काळजी घेतली जाईल.
# He has been admitted to Lilavati Hospital for treatment.
# त्याला उपचारासाठी लीलावती रुग्णालयात दाखल केलं आहे.
# NCP MP Supriya Sule tweeted wishing him a speedy recovery.
# NCP चे सांसद सुप्रिया सुले यांनी त्याला शीघ्र सुधारण्याची शुभेच्छा दिली.
# Many political leaders are also infected with the corona.
# कित्येक राजकारणी आपल्याबरोबरही कोरोना संक्रमित आहेत.
# That fear seems to be coming true now.
# आता ते भय सत्य होतं दिसतं.
# In this Dr. Abhijeet Darak has given detailed information about this while talking to ANI.
# डॉ. अभिजित दारकने ANIसोबत बोलताना ह्याच्याबद्दल विस्तृत माहिती दिली आहे.
# In the last two days, we have experienced a severe shortage of oxygen.
# शेवटी दोन दिवसांत आम्हाला ऑक्सिजनची खूप कमतरता अनुभवली आहे.
# In addition to the curfew, a number of other restrictions have been imposed.
# कर्फ्यूच्या वेळेच्या बाहेर प्रतिबंधांची काही अधिक मर्यादा लागू केली आहेत.
# It empowers the local administration to adapt to the situation.
# ते स्थानिक प्रशासनाला परिस्थितीस अनुकूलित करण्यास सक्षम बनवते.
# In this meeting, it was decided to keep the grocery shops in the state open from 7 am to 11 am.
# या बैठकात, राज्यातील किराणा दुकाने सकाळी 7 वाजता ते संध्याकाळी 11 वाजता उघडण्याचा निर्णय घेण्यात आला.
# The government is running unplanned.
# सरकार अनियोजितपणे चालत आहे.
# The incident took place at Ghargaon in Sangamner taluka of Ahmednagar.
# कारवाई घरगाव मध्ये अहमदनगरच्या संगमनेर तालुक्यात झाली.
# Patients were being taken for treatment.
# रुग्णांना उपचारसाठी घेतले जात होते.
# Therefore, there is a possibility of imposing a strict lockdown once again.
# तसेच, पुन्हा कडक लॉकडाऊन लागू करण्याची संभावना आहे.
# In this meeting, Chhagan Bhujbal has said that he will demand a strict lockdown of 10 to 15 days from the Chief Minister.
# या बैठकात, छगन भुजबळ यांनी मुख्यमंत्रीकडून कडक लॉकडाऊनची मागणी करणार असे म्हणाले आहे की, 10 ते 15 दिवसांचा कठोर लॉकडाऊन मागणार आहे.
# Now oxygen has to be brought from Visakhapatnam etc.
# आता ऑक्सिजन विशाखापट्नमपासून आणणे आवश्यक आहे.
# People are just moving away from the cause.
# लोक कारणापासून फक्त दूर होत आहेत.
# On the one hand, due to shortage of vaccines, many vaccination centers are closed and the general public is not getting facilities.
# एका बाजूला, टीकाकरणाच्या कमीत कारणे, अनेक टीकाकरण केंद्र संचालित झालेले आहेत आणि सामान्य लोकांना सुविधा मिळत नाही.
# He deleted this post after an argument.
# त्याने लढाईनंतर हा पोस्ट डिलीट केलं.
# I have no idea by what criteria he received the vaccine dose.
# मला कळत नाही की त्याने लसीकरणाचं डोस कसं प्राप्त केलं आहे.
# On the other hand, the death toll is rising.
# तरीही, मृत्युदर वाढत आहे.
# However, there is a severe shortage of oxygen and ventilator beds.
# पण, ऑक्सिजन आणि व्हेंटिलेटर बेड्सची गंभीर कमतरता आहे.
# Under this, it has been announced to vaccinate everyone above 18 years of age
# याच्यातून, १८ वर्षांपेक्षा जास्त वयोमानांची लसीकरण करण्याची घोषणा केली गेली आहे.
# Raj Thackeray, the demands made by you in a letter were accepted by the Central Government.
# राज ठाकरे, आपण लिहिलेल्या पत्रातील मागण्यांना केंद्र सरकारने स्वीकारले.
# For this, I am grateful to the Prime Minister and hope that the Central Government will always help in overcoming this epidemic.
# यासाठी, मी पंतप्रधानांवर कृतज्ञ आहे आणि आशा आहे की केंद्र सरकार हे संक्रांतीला लढवण्यात सदैव मदत करेल.
# I would like to thank the Prime Minister and the Minister of Health for taking a positive step and vaccinating everyone below the age of 18, said Chief Minister Uddhav Thackeray.
# मुख्यमंत्री उद्धव ठाकरे यांनी म्हणाले, "मुख्यमंत्री उद्धव ठाकरे यांनी म्हणाले, प्रधानमंत्री आणि आरोग्य मंत्र्यांचे धन्यवाद करू इच्छितो कि त्यांनी सकारात्मक कदम उचलून घेतले आणि १८ वर्षांपर्यंत सर्वांना लसीकरण केले."
# Also, the administration should take strict action against the citizens who roam without any reason, suggested Mayor Babasaheb Wakle.
# महापौर बाबासाहेब वाकळे यांनी सुचवलं की, प्रशासनाने किमान कारण नसलेल्या नागरिकांवर कडक कारवाई घेण्याची आवश्यकता आहे.
# At that time, it was decided to conduct 'antigen test' on the streets of the citizens walking on the road without any reason.
# त्या काळात, रस्त्यावर चालणार्‍या नागरिकांच्या 'एंटिजन चाचणी' करण्याचा निर्णय घेण्यात आला की ज्यामुळे कारणाशिवाय रस्त्यावर चालणार्‍या नागरिकांची चाचणी करण्याचा निर्णय घेण्यात आला.
# There is a dearth of oxygen and remedicivir injections, so citizens should stay at home and cooperate to break the chain of corona infection.
# ऑक्सिजन आणि रेमेडिसिव्हिर इंजेक्शनची कमतरता आहे, म्हणजे नागरिकांनी घरी राहून कोरोना संक्रमणाच्या श्रृंखलेचा तोडवण्यासाठी सहकार्य करावं.
# Opposition leader Baraskar demanded that an oxygen project, a hospital be set up on behalf of the corporation, while Ajay Chitale demanded that a bed with oxygen facilities be made available at the corporation's Kovid Center.
# प्रतिपक्ष नेते बरसकरने मागणी केली की एक ऑक्सिजन प्रकल्प, एक रुग्णालय कॉर्पोरेशनच्या तर्फे स्थापित केले जाऊ लागेल, ज्यांच्यावर अजय चिटळे मागणी केली की कोर्पोरेशनच्या कोविड केंद्रात ऑक्सिजन सुविधांसह एक बेड उपलब्ध केले जाऊ लागेल.
# Apart from this, the fish market at Nalasopara will be converted into a corona treatment center and a 150-bed intensive care unit will be set up there.
# ह्यापेक्षा बाहेर, नालासोपारा येथील मासे बाजाराला कोरोना उपचार केंद्रात बदलले जाईल आणि तत्कालीन देखभाली युनिटसाठी 150-बेडचा स्थापन केला जाईल.
# After that, a review meeting was held with the officials at the NMC headquarters.
# त्यानंतर, एनएमसी मुख्यालयात अधिकाऱ्यांसह समीक्षा बैठक झाली.
# As a result, municipal and state governments are making efforts to increase supply.
# निकाल वाढवण्यासाठी नगरपालिका आणि राज्य सरकार कडून प्रयत्न करत आहेत.
# Centers will be set up in every section of rural areas for segregation and segregation of patients.
# गावीच्या प्रत्येक विभागात केंद्र स्थापित केले जाईल रुग्णांच्या विभागीकरण आणि विभाजनासाठी.
# However, Bhuse admitted the fact that there is a shortage of remedicivir.
# पण, भुसे याच्याच खात्री आहे की रेमेडिविरची कमतरता आहे.
# The supply of injections delivered is very meager and the supply of these injections at the government corona dedicated hospital is also on the verge of running out.
# दिलेल्या इंजेक्शनची आपल्याला खूप कमी पुरवठा मिळते आणि सरकारच्या कोरोना विशेष रुग्णालयातील या इंजेक्शनची पुरवठा सुद्धा उत्तराधिकारात आहे.
# Out of these, two hospitals in Palghar taluka have been functioning since Monday and 414 remedicivir injections were distributed to 1100 patients admitted in the remaining hospitals.
# यामध्ये, पालघर तालुक्यातील दोन रुग्णालये सोमवारपासून कार्यरत आहेत आणि शेवटी उर्जावरील रुग्णालयात भरती झालेल्या 1100 रुग्णांसाठी 414 रेमेडिसिविर इंजेक्शन वितरित केल्या गेल्या आहेत.
# In that connection, Palghar district was expected to supply about one and a half per cent or one and a half to one and a half hundred injections per day as compared to the state.
# त्या संबंधात, पालघर जिल्ह्याची तुलनेत राज्याशी एक व एक निमित्त व्यवस्थित किंवा एक व एक निमित्त सैकड्या इंजेक्शन प्रतिदिन पुरवण्याची अपेक्षा केली होती.
# He informed that the information of the patients admitted to the hospital was requested through Google sheet and in this connection, Remedesivir was distributed to the private corona recognized hospitals in Vasai-Virar Municipal Corporation area as well as Palghar, Dahanu and Vikramgad.
# त्याने सूचित केलं की रुग्णांची माहिती अस्पतालात भरण्यात आलेली होती आणि या संबंधात, वसई-विरार महानगरपालिका क्षेत्रातील खासगी कोरोना पहिचानी अस्पतालांना Google शीटद्वारे वितरली गेलेली आहे, साथी पालघर, दहाणू आणि विक्रमगड या भागातील खासगी कोरोना पहिचानी अस्पतालांना रेमेडेसिव्हीर वितरित केली गेली.
# The municipality has instructed hospitals to provide alternative medicines instead of remedicivir.
# नगरपालिकेने रेमेडिसिव्हिरच्या बदलाच्या औषधांची पुरवठा करण्याच्या निर्देशित केल्या आहेत.
# Those who have it are saying that they will give it only when requested by the hospital.
# त्या लोकांनी म्हणालं आहे की ते फक्त त्यांनी अस्पतालाने विनंती केल्यावरच पुरवणार आहे.
# Since he is alone, his friends are rushing for Remedesivir.
# त्याने एकट्याने असून, त्याचे मित्र Remedesivir साठी त्रासात आहेत.
# It has allowed vegetable, grocery and milk vendors to keep their shops open from 7 am to 11 am, while a strict lockout has been decided on Saturdays and Sundays.
# हे सब्जी, किराणा आणि दूध विक्रेत्यांना सकाळी ७ ते दुपारी ११ वाजता त्यांच्या दुकाने उघडण्याची परवानगी दिली आहे, पण शनिवार आणि रविवारी एक ठोस लॉकआउट ठरवला गेला आहे.
# According to a report released on Sunday, 337 patients have been infected with corona and the total number has reached 37,851.
# रविवारी प्रकाशित अहवालानुसार, कोरोना रुग्णांची संख्या 337 वाढली आहे आणि एकूण संख्या 37,851 तक पोहोचली आहे.
# Accordingly, restrictions were imposed by the Mira-Bhayander Municipal Corporation administration.
# सोयीसच, मीरा-भायंदर महानगरपालिका प्रशासनाने प्रतिबंध लागू केले.
# Dairy vendors are allowed daily from 7 to 11 p.m.
# डेअरी विक्रेते दैनंदिन 7 ते 11 वाजता अनुमती आहे.
# In it, relatives of Corona Mayata have been robbed by private hospitals.
# त्यात, कोरोना महामारीच्या नातेवाईकांच्या खासगी रुग्णालयांनी लुटले आहेत.
# More than 800 patients are found every day.
# दर दिवसाला ८००पेक्षा अधिक रुग्ण आढळतात.
# At this time he asked for Rs. 4500 for PPE kit from the municipal ambulance.
# या क्षणी त्याने नगरपालिका एम्बुलेंसमधून PPE किटसाठी रुपये ४५०० मागितले.
# He has accused hospitals and ambulance drivers of looting.
# त्याने रुग्णालय आणि एम्ब्युलेन्स ड्रायव्हर्सला लुटत चोरी करण्याचा आरोप लागविला आहे.
# If any type of money is found, it will be investigated and appropriate action will be taken.
# कोणत्याही प्रकारची पैसे मिळाली तर ती तपासली जाईल आणि उचित कारवाई केली जाईल.
# So the situation is getting more frightening.
# त्याचे स्थिती अधिक भयानक व्हावे लागत आहे.
# The use of remedivir injections is only being discussed.
# रेम्डिविर इंजेक्शनचा वापर केवळ चर्चा केला जात आहे.
# Patients from neighboring Marathwada and Karnataka, including the city and district of Solapur, are also being admitted to the hospital.
# मराठवाडा आणि कर्नाटकातील रोगी, सोलापूर येथील शहर आणि जिल्ह्यातील रोगीही हॉस्पिटलमध्ये प्रवेश करवले जात आहेत.
# He explained that it was only possible to use oxygen for major surgeries, preferably due to the lack of oxygen.
# त्याने समजावलं की मुख्य शल्यक्रियांसाठी ऑक्सीजन वापरणे एकमेव संभव आहे, उपयुक्तपणे ऑक्सीजनची कमी असल्यामुळे.
# There were World Health Organization (WHO) guidelines for avoiding autopsies during the Coronation Period.
# कोरोनाव्हायरस वेळेत अटोप्सी टाळण्यासाठी विश्व स्वास्थ्य संगठन (WHO) निर्देशिका होती.
# Awareness of body donation and organ donation has been created in the last few years.
# शेवटी काही वर्षांत शरीर दान आणि अंगदानची जागरूकता वाढली आहे.
# After embalming, the body undergoes a chemical process called 'embalming'.
# अंबलमिंगनंतर, शरीरावर 'एंबल्मिंग' असे रसायनिक प्रक्रिया होते.
# The Department of Medical Education said that the acceptance of body donation has started from December.
# वैद्यकीय शिक्षण विभागने म्हणालं की शरीरदानाची स्वीकृती डिसेंबरपासून सुरू झाली आहे.
# Due to the current difficult situation, the donation letter has been filled but the relatives are avoiding the donation.
# वर्तमान कठीण परिस्थितीच्या कारणे, दानपत्र भरला आहे पण नजिकचे नातेवाईक दानाच्या टाळत आहेत.
# Instructions in this regard have been given to all government medical colleges.
# सर्व सरकारी वैद्यकीय महाविद्यालयांना ह्या संदर्भातील निर्देश दिले आहेत.
# The ‘noncovid’ autopsy process is underway.
# ‘नॉनकोविड’ अटॉप्सी प्रक्रिया सुरू आहे.
# Currently, most classes of medical education degree students are closed due to corona.
# सध्या, कोरोनामुळे अध्यापन डिग्रीच्या अध्ययनाच्या अध्यापनाच्या अध्यापनांची बर्याच वर्गे बंद आहेत.
# Concerns have been raised over the steady rise in deaths in Vidarbha.
# विदर्भातील मृत्यूंची स्थिर वाढ ह्यावर चिंता व्यक्त केली गेली आहे.
# In Bhandara, 21 patients died and 833 died, in Amravati 16 died and 593 new patients died, in Chandrapur 22 died and 1,213 died, in Gadchiroli 12 died and 305 died, in Gondia 21 died and 520 died, in Yavatmal 37 died and 810 died and in Washim 1 died.
# भंडारा मध्ये 21 मरीज मृत्यू झाले आणि 833 मृत्यू झाले, अमरावतीत 16 मृत्यू झाले आणि 593 नवीन मरीज मृत्यू झाले, चंद्रपूरमध्ये 22 मरीज मृत्यू झाले आणि 1,213 मृत्यू झाले, गडचिरोलीत 12 मरीज मृत्यू झाले आणि 305 मृत्यू झाले, गोंदियामध्ये 21 मरीज मृत्यू झाले आणि 520 मृत्यू झाले, यवतमाळमध्ये 37 मरीज मृत्यू झाले आणि 810 मृत्यू झाले आणि वाशिममध्ये 1 मरीज मृत्यू झाले.
# Both of these incidents paint a heartbreaking picture of the city's health services being completely disrupted.
# याबद्दल दोन्ही घटनांनी नगराच्या आरोग्य सेवांची पूर्णपणे विघटित झालेली चित्र चित्रित करतात.
# Due to her deteriorating condition, the doctors there asked her to move to the Medical College, Chandrapur and also gave her a prescription.
# तिच्या क्षयात्मक स्थितीमुळे त्यांनी तिच्याला चंद्रपूर मेडिकल कॉलेजमध्ये जाऊन दिले आणि त्यांनी तिच्याला एक औषधनामा दिला.
# There was no oxygen or ventilator bed.
# ऑक्सिजन किंवा वेंटीलेटर बेड नव्हते.
# Relatives have expressed their displeasure over the death of a young man and a woman due to lack of beds.
# एका तरुणाच्या आणि एका स्त्रीच्या मृत्यूच्या कारणी बेड्सची कमतरता असल्यामुळे नातेवाईकांनी त्यांच्यावर असंतोष व्यक्त केलं आहे.
# Fines to six private hospitals; Collector's order
# सहा खासगी रुग्णालयांना दंड; कलेक्टरांचे आदेश
# A hospital has ordered the refund of extra charges charged from the patient.
# एक रुग्णालयाने रुग्णाकडून वस्तूच्या अतिरिक्त शुल्कांची परतफेक करण्याचे आदेश दिले आहे.
# Delay in corona test of patients, pending some reports, failure to report positive test reports to district administration, use of remedicivir injection without consent of relatives instead of referral to government hospital or covid hospital when covid test is negative and HRCT score is high.
# रुग्णांच्या कोरोना चाचणीत विलंब, काही अहवाल थांबलेले, सकारात्मक चाचणी अहवाल जिल्हा प्रशासनाला सूचित करण्याचा निष्फळतेसह, कोविड चाचणी नेगअच्या अंगीणी म्हणजेच एचआरसीटी स्कोअर उच्च असल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि रुग्णांच्या निर्देशकांच्या सहमती नसल्यामुळे सरकारी रुग्णालय किंवा कोविड रुग्णालयात निर्देशित करण्याच्या बदलात रेमेडिसिविर इंजेक्शनचा वापर केलेला अनुमती न असल्यामुळे आणि
# Other people who saw this scene were horrified this time.
# या दृश्याचा दुसर्या वेळी पाहिलेल्या लोकांचा भयानक अनुभव होता.
# After an examination, he was found to have an HRCT score of 14.
# एक परीक्षेच्या नंतर, त्याला १४ असा HRCT स्कोअर मिळाला.
# While the drug dealer was removing the drug, Marotrao sat on the steps.
# औषध विक्रेता औषध काढताना असताना, मारोत्राव सीढ्यावर बसला.
# However, he did not do another test of Corona.
# पण त्याने कोरोना चाचणीची दुसरी चाचणी केली नाही.
# His HRCT score was 14 and his oxygen level was low.
# त्याचा एचआरसीटी स्कोअर १४ होता आणि त्याचा ऑक्सिजन स्तर कमी होता.
# This incident has spread panic in Hatgaon.
# हातगावात ही घटना भयानकता फैलवली आहे.
# These include Shwas Hospital at Ram Nagar, Phoenix Hospital at Kaulkhed and Thote Hospital at Mahajani Plot.
# ह्यात श्वास रुग्णालय राम नगर, फीनिक्स रुग्णालय कौलखेड आणि ठोटे रुग्णालय महाजनी प्लॉट यात आहेत.
# The body was finally handed over at 3 pm after a period of more than twelve hours after mediation by the Aam Aadmi Party.
# आम आदमी पक्षाने मध्यस्थतेने अनेक तासांनंतर शवाची मोठी शवस्थळावर जाहीरी केली.
# The deceased's wife and brother reached Shweta Hospital on Monday morning to take the body away.
# मृताच्या पत्नी आणि भाऊ सोमवारी सकाळी श्वेता हॉस्पिटलला पोहोचले आणि शव घेण्यासाठी आले.
# He immediately reached the hospital and visited the family.
# त्याने तात्पुरत्या रुग्णालयात जाऊन कुटुंबाला भेटलं.
# Eventually, a settlement was reached through the mediation of the police, the municipal corporation and the Aam Aadmi Party, and the doctors handed over the bodies to the families.
# कालावधीत, पोलिस, नगरनिगम आणि आम आदमी पक्षाच्या मध्यस्थतेच्या माध्यमातून एक समझूती साधली आणि डॉक्टर्सने मृतांचे शव कुटुंबांना सोडून दिले.
# Was financially capable.
# आर्थिक दृढतेने समर्थ होतो.
# He appealed to all citizens above the age of 45 to get vaccinated.
# त्याने ४५ वर्षांच्या वयाच्या सर्व नागरिकांना लसीकरण करण्याची विनंती केली.
# However, after overcoming corona, he returned to duty, but as he could not be vaccinated immediately, he was vaccinated two months later.
# पण कोरोना लढवून नंतर, त्याने कर्तव्यावर परतला, पण त्याला तत्काल लसीकरण केले जाण्याची संधी नव्हती, त्याला दोन महिन्यानंतर लसीकरण केले गेले.
# According to this, now everyone above the age of 18 will be vaccinated against corona.
# यानुसार, आता १८ वर्षांच्या वयाच्या सर्व लोकांना कोरोनाविरुद्ध लस लागेल.
# Now everyone over the age of 18 will be vaccinated against coronavirus.
# आता १८ वर्षांपेक्षा जास्त वयोमुक्त लोक कोरोनाव्ह्हायरसविरुद्ध लसीकरण केले जाईल.
# He also hoped that full planning would be done in this regard in the state and supply of vaccines would continue to be received in time.
# त्याने तसंच आशा केली की राज्यात पूर्ण योजना केली जाईल आणि वैक्सिनची आपल्याला समयानुसार पुरवठा मिळेल.
# However, the vaccination phase has been extended in view of the increasing prevalence of corona.
# पण, कोरोनाच्या वाढत्या प्रसाराच्या प्रस्तावनेमुळे लसीकरण टप्पा वाढविला गेला आहे.
# Extensive vaccination campaign from May 1
# मे १ पासून व्यापक टीकाकरण अभियान
# Free vaccinations are being provided at government centers.
# सरकारी केंद्रांमध्ये मोफत टीकाकरण प्रदान केले जात आहेत.
# Covacin and covshield vaccines are currently being given in India.
# कोवाक्सीन आणि कोव्हील्ड लसीकरण आत्ता भारतात दिली जात आहेत.
# A large number of coronaviruses are being diagnosed every day and the number of patient deaths is also increasing.
# प्रतिदिन एकाच दिवसात एकाच दिवसात अनेक कोरोनाव्ह्हायरस रुग्णांची निदान केली जात आहे आणि मरीजांची मृत्यूंची संख्या वाढत आहे.
# A total of 31,59,240 crore infected patients have recovered and returned home in the state till date.
# ह्या तारखेपर्यंत राज्यातील एकूण 31,59,240 कोटी लक्षित रुग्णांनी व्यक्ती झाले आहेत आणि घरी परत गेले आहेत.
# At present, there are 37,43,968 persons in Home Quarantine and 27,081 persons in Institutional Quarantine in the State.
# सध्या राज्यात घरीच्या क्वारंटाईनमध्ये ३७,४३,९६८ व्यक्ती आहेत आणि संस्थागत क्वारंटाईनमध्ये २७,०८१ व्यक्ती आहेत.
# But the situation still does not appear to be under control.
# पण स्थिती अद्याप तंत्रित दिसत नाही.
# However, in a meeting chaired by the Deputy Chief Minister, a decision has been taken today (Monday) to limit the time of grocery shops from 7 am to 11 am as citizens are roaming around the house all day in the name of grocery shopping despite the restrictions.
# तरीही, उपमुख्यमंत्रीने अध्यक्षित झालेल्या बैठकीत आज (सोमवार) नागरिकांना प्रतिबंधांच्या दिशेने ग्रोसरी दुकानांच्या वेळेची सीमा 7 वाजता सकाळी 11 वाजता संध्याकाळी करण्याचा निर्णय घेण्यात आला आहे कारण रोजच्या ग्रोसरी शॉपिंगच्या नावाखाली नागरिकांनी घरात आठवत आहेत.
# Prime Minister Modi addressed the nation today (April 20).
# पंतप्रधान मोदी आज (एप्रिल २०) रोजी राष्ट्राला भाषण दिले.
# At the same time, we are working to keep the economy afloat.
# एका वेळी, आम्ही अर्थव्यवस्थेचा पाया ठेवण्यासाठी काम करत आहोत.
# The trust given by the states will be very helpful.
# राज्यांनी दिलेलं विश्वास अत्यंत सहायक असेल.
# I urge the states to use lockdown as a last resort.
# मी राज्यांना लॉकडाऊनचा वापर किंवा विचार करण्याची विनंती करतो.
# Prime Minister Narendra Modi did not name any of these in his speech today, but he did comment on oxygen supply.
# आज पंतप्रधान नरेंद्र मोदी यांनी आपल्या भाषणात कोणतेही नाव सांगितले नाहीत, पण त्यांनी ऑक्सिजन आपूर्तीवर टीका केला.
# From May 1, everyone above the age of 18 will be vaccinated.'
# 1 मे पासून १८ वर्षांपेक्षा मोठ्या सर्वांना लसीकरण केले जाईल.
# Your efforts can have a big impact.'
# तुमच्या प्रयत्नांनी मोठा परिणाम होऊ शकतो.
# If you do that, there will be no need to create containment zones, no need to impose curfew or lockdown, Modi said.
# तुम्ही जर ते करता, तर आवश्यकता नसेल की सीमांत क्षेत्र तयार करण्याची, कर्फ्यू किंवा लॉकडाऊन लागू करण्याची, मोदी म्हणाले.
# Do not create an atmosphere of fear.'
# भयाचा वातावरण तयार करू नका.
# For this, we request the state administration to appeal to the workers for this.
# यासाठी, आम्ही राज्य प्रशासनाला ही विनंती करतो की कर्मचार्यांना ह्यासाठी अपील करावी.
# Earlier this limit was for people above 45 years.
# आधीची ही मर्यादा ४५ वर्षांपेक्षा जास्त वयाच्या लोकांसाठी होती.
# Before that, let's see how many vaccinations have been done in Maharashtra so far.
# त्यापूर्वी, आपल्याला पहा की महाराष्ट्रात किती लसीकरण केले गेले आहेत.
# In other words, 1 crore 22 lakh 73 thousand 973 people have been vaccinated against corona in Maharashtra so far.
# इतर म्हणजे, महाराष्ट्रात कोरोनाविरुद्ध एक कोटी बावीस लाख तेवीस हजार नऊ सौ त्रेस सुद्धा लोकांना टीका लागले आहेत.
# In other words, about 1 crore 22 lakh people have been vaccinated in Maharashtra in three months.
# इतर शब्दांत, तीन महिन्यांत महाराष्ट्रात १ कोटी २२ लाख लोकांना टीका लावलेली आहे.
# We learned about this by talking to experts in the medical field.
# आपल्याला या बाबतीत मेडिकल क्षेत्रातील तज्ञांसोबत बोलून शिकलं.
# We still have 10 days.
# आम्हाला अजून १० दिवस आहेत.
# At this price, the state government, private hospitals and industrial estates will buy the vaccine.
# या किंमतीनुसार, राज्य सरकार, खासगी रुग्णालय आणि औद्योगिक एस्टेट्स लसी विकत घेणार.
# At this rate, the state government, private hospitals will buy vaccines.
# या दरानुसार, राज्य सरकार, खासगी रुग्णालय लसीकरण खरेदी करेल.
# The central government has said that the decision will be taken after considering the infection situation in the area and the state administration's vaccination work.
# केंद्र सरकारने म्हणालं आहे की निर्णय या क्षेत्रातील संक्रमण दशा आणि राज्य प्रशासनाच्या लसीकरण कामाच्या मूल्यांकनानंतर घेण्यात येईल.
# This will include healthcare workers, frontline workers and citizens over 45 years of age.
# हे आरोग्य सेवा कर्मचारी, फ्रंटलाइन कर्मचारी आणि ४५ वर्षांपेक्षा जास्त वयाचे नागरिक समाविष्ट करेल.
# And currently there is a demand of 37 lakh doses per day.
# आणि सध्या दिवसात ३७ लाख डोसची मागणी आहे.
# Vaccine doses are also provided to low-income countries through this group.
# ह्या समूहाद्वारे कमी आयाच्या देशाला लसीकरणाच्या डोसेस प्रदान केले जातात.
# The vaccine will be available in India later this month, the Mint reported.
# मिंट ने जाहिर केल्यानुसार लस या महिन्याच्या सोबत भारतात उपलब्ध असेल.
# At the same time, there are reports that the government has approached these companies to make the vaccine available in India .
# एका वेळी, सरकारने हे कंपन्यांना भारतात लस उपलब्ध करण्याची विचार केली असून त्यांच्याकडून अहवाल आहेत.
# There is an illusion in people's minds.
# लोकांच्या मनात भ्रांती आहे.
# But, a member of the Covid-19 task force, Dr. According to Shashank Joshi, there is no evidence that remedivir saves patients.
# पण, Covid-19 कार्यदलातील एक सदस्य, डॉ. शशांक जोशी यांनी सांगितल्यानुसार, रेमेडिव्हिर रुग्णांना उद्धार करत याची कोणतीही प्रमाणे नाहीत.
# As a result, healthcare fell through Kollam.
# निकालीसाठी, कोल्लाममध्ये आरोग्य सेवा झोपटली.
# Is Ramdesivir beneficial in the fight against corona?
# कोरोनाविरुद्ध लढ्यात रामदेसिविर लाभकारक आहे का?
# It is an antiviral drug that kills viruses.
# हे व्हायरस व्याधीनाशक आहे ज्याने व्हायरसला मारते.
# It is used on an experimental basis.
# हे प्रयोगात्मक आधारावर वापरले जाते.
# Remedesivir helps in speeding up the recovery of corona.
# रेमडेसिविर कोरोनाच्या व्याख्यानाची वेगवेगळी करण्यास मदत करते.
# It only takes five days.
# ते फक्त पाच दिवस लागतात.
# Those who are at home should not be given Remedesivir at all.
# जे घरी आहेत त्यांना कधीही Remedesivir दिलं नाही जाऊ लागतं.
# Queues of people are being seen.
# लोकांच्या कतारी पाहिली जात आहेत.
# It is not necessary at all.
# हे एकदम आवश्यक नाही.
# This medicine is a magic wand.
# ही औषध एक जादूचा डंडा आहे.
# The Corona tsunami spread to us with great speed.
# कोरोना सुनामी आम्हाला मोठ्या वेगाने पसरली.
# We were not ready to face this wave.
# आम्ही ह्या लहराच्या सामन्यावर तयार नव्हतो.
# Give this medicine only to those who need it.
# या औषधाचा वापर केवळ त्यांना करावा ज्यांना हवं आहे.
# Therefore, even if the patient or relatives put pressure, the doctor should insist.
# तसंच, रुग्ण किंवा नातेवाईकांनी दबाव टाकल्यास डॉक्टरला दृढपणे आवाहन करावे लागते.
# There is no problem in giving medicine to the right patients with medical advice.
# चिकित्सा सल्ला देऊन योग्य रुग्णांना औषध देण्यात कोणतेही समस्या नाही.
# This will be decided on scientific grounds.
# हे वैज्ञानिक आधारांवर ठरवले जाईल.
# There have been four major trials on this.
# ह्यावरून चार मुख्य चर्चांची झाली आहेत.
# Unless you make the mask mandatory.
# जर तुम्ही चेहरा ढकवणे अनिवार्य करत नसाल तर.
# We are following the economic cycle but not paying attention to health, which is a big disappointment.
# आम्ही आर्थिक चक्राचा पालन करीत आहोत पण आरोग्याला लक्षात घेण्याची काळजी घेत नाही, हे मोठं निराशाजनक आहे.
# But, the recovery is good.
# पण, रिकव्हरी चांगली आहे.
# During the meeting, he held discussions with senior officials and doctors.
# बैठकात, त्याने वरिष्ठ अधिकाऱ्यांसोबत आणि डॉक्टरांसोबत चर्चा केली.
# It was then decided to vaccinate all persons above 45 years of age in the country from April 1.
# त्यानंतर, देशातील सर्व व्यक्तींना ४५ वर्षांपेक्षा जास्त वयाच्या लोकांना १ एप्रिलपासून टीका लावण्याचा निर्णय घेण्यात आला.
# The platform can be used by vaccination campaigns, vaccinating healthcare providers and vaccinators.
# हे मंच टीकाकरण अभियान, टीकाकरण करणारे आरोग्य सेवा प्रदाते आणि टीकाकरणकर्ते द्वारे वापरले जाऊ शकते.
# This mobile app will also record statistics about vaccinations.
# ही मोबाइल अ‍ॅप लसीकरणांबाबतीतले अंकगणित माहितीही नोंदवेल.
# Make sure that the app you are downloading is an app brought by the Government of India, then download it.
# खात्री करा की आपण डाउनलोड करणारी अॅप भारत सरकार द्वारे आणलेली असेल, तर ती डाउनलोड करा.
# So that you will be informed in advance about the vaccination center, date, time etc.
# तुम्हाला टीका केंद्र, तारीख, वेळ इत्यादीची अगोदर सूचित केल्याजाणार आहे.
# Click on the Registration Yourself option.
# स्वत:ला नोंदणी करा या पर्यायावर क्लिक करा.
# Here you have to provide information like photo ID proof, photo ID number, name, date of birth, gender and affiliation etc.
# येथे तुम्हाला माहिती प्रदान करावी लागेल जसे फोटो आयडी प्रमाणपत्र, फोटो आयडी क्रमांक, नाव, जन्म तारीख, लिंग आणि संबंध इत्यादी.
# You can register a vaccination for three people in one mobile number registration.
# एका मोबाइल नंबर नोंदणीद्वारे तीन व्यक्तींची लसीकरण नोंदणी करू शकता.
# After entering the state, district, block and pin code, click on the search option.
# राज्य, जिल्हा, ब्लॉक आणि पिन कोड प्रविष्ट केल्यानंतर, शोध पर्यायावर क्लिक करा.
# After clicking on the Book option, the Appointment Confirmation page will open.
# बुक पर्यायावर क्लिक केल्यानंतर, अपॉईंटमेंटची पुष्टी पृष्ठे उघडणार आहेत.
# You can also download that page.
# तुम्ही त्या पृष्ठाची डाउनलोडही करू शकता.
# Rear time tracking of vaccine doses can be done through this app.
# या अॅपद्वारे लसीकरणाच्या डोजेसचे पिछले वेळ ट्रॅक केले जाऊ शकते.
# The procurement process of these projects which can be set up in two to three weeks should be started immediately by the concerned Collector and Municipal Commissioner.
# या प्रकल्पांच्या आयोजनांची खरेदी प्रक्रिया दोन ते तीन आठवड्यांत सुरू केली जाऊ शकते, ती संबंधित कलेक्टर आणि नगरकर्मचारीकडे तत्परतेने प्रारंभ करण्याची आवश्यकता आहे.
# Oxygen production plants in many industries are in a closed state.
# काही उद्योगातील ऑक्सिजन उत्पादन संयंत्र संपूर्ण बंद आहेत.
# Maharashtra should immediately start the process of producing more oxygen in the state itself, taking into account the fear of shortage of oxygen from outside after the number of patients increases in other states in the near future.
# महाराष्ट्रने तत्काल आपल्या राज्यात अधिक ऑक्सिजन उत्पादनाची प्रक्रिया सुरू करण्याची आवश्यकता आहे, इतर राज्यांतील मरीजांची संख्या भविष्यात वाढते तर बाहेरून ऑक्सिजनची कमतरता असल्याची भीती घेऊन.
# He instructed the trio to spend for new oxygen projects on the basis of the rates purchased through the prescribed process.
# ...
# Strict restrictions should be imposed in talukas with high number of patients in that district and some concessions should be given in talukas where there are no patients.
# त्या जिल्ह्यातील तालुक्यांमध्ये ज्यांच्यात अधिक रुग्ण असतात त्यांच्यावर कठोर प्रतिबंध लागू करण्याची आवश्यकता आहे आणि ज्या तालुक्यांमध्ये कोणत्याही रुग्ण नसतील त्या तालुक्यांमध्ये काही सुविधा देण्याची आवश्यकता आहे.
# The government has set up a task force of pediatricians to guide children on preventive measures and treatment methods to prevent infection.
# सरकारने लसीक रोगांची टाळण्यासाठी आणि संक्रमण टाळण्यासाठी बालरोगवैद्यकीय डॉक्टरांच्या सल्लाहांचे मार्गदर्शन करण्यासाठी एक टास्क फोर्स स्थापित केले आहे.
# Chief Minister Uddhav Thackeray had directed to appoint a task force of pediatricians to protect the children and develop necessary treatment methods.
# मुख्यमंत्री उद्धव ठाकरे यांनी मुलांची सुरक्षा करण्यासाठी आणि आवश्यक उपचार विकसित करण्यासाठी पेडियाट्रिशियन्सची कार्यदल नियुक्त करण्याचे निर्देशित केले.
# In this regard, Additional Chief Secretary of the Health Department Dr.
# आयुष्य विभागाच्या अतिरिक्त मुख्य सचिव डॉ.
# In the last few years, compared to Chhattisgarh, Gadchiroli police have been able to carry out successful operations and kill 20 extremist Naxalites in three months.
# आखातर वर्षांतील तुलनेत, छत्तीसगड सोपऱ्याने, गडचिरोली पोलीसने यशस्वी अभियान काढून 20 उग्र नक्सलाईट्सच्या तिन महिन्यांत मारून केले आहेत.
# In it, many Naxalites have died due to corona.
# त्यात, कोरोना मुळे अनेक नक्सलाइट्स मृत्यू झाले आहेत.
# Now there is not a single old senior Naxalite left in Gadchiroli.
# आता गडचिरोलीत कोणत्याही जुन्या वरिष्ठ नक्सलाईट राहिल्या नाहीत.
# As a result, youth have to be brought here from nearby Chhattisgarh to sustain the movement.
# त्याचा परिणामस्वरूप, चलनाची चालवण्यासाठी युवकांना जवळच्या छत्तीसगढपासून येऊन येते.
# Gadchiroli police has achieved success by conducting continuous operations and targeting Naxal sites.
# गडचिरोली पोलीसने नक्सल स्थळांवर नियमित कार्यवाही करून सफळता मिळवली आहे.
# Naxal leader Narmadakka, the mastermind of the Jambhulkheda landmine blast, has been arrested.
# नक्सल नेते नर्मदाक्का, जंभुळखेडा लँडमाइन धमाक्याच्या मास्टरमाइंड झालेल्या, त्यांची अटक केली गेली आहे.
# This ransom is a major economic force of the Naxal movement.
# हा उत्पादन नक्सल आंदोलनाचा मुख्य आर्थिक शक्तीचा एक भाग आहे.
# In particular, 20 Naxals have been killed in the three months of March, April and May.
# विशेषत: मार्च, एप्रिल आणि मे महिन्यांतील २० नक्सल्स मारले गेले आहेत.
# Since that incident, Gadchiroli police have been putting constant pressure on the Naxalites.
# त्या घटनेनंतर, गडचिरोली पोलिसांनी नक्सलाईट्सवर लगातार दाब टाकणे थोडंसं कमी केलं आहे.
# However, Gadchiroli police has achieved great success by eliminating Kasansur Dal.
# पण, गडचिरोली पोलीसने कसांसूर दलाचे नष्ट करून मोठी सफळता मिळवली आहे.
# As Satish, a member of the Naxalite Divisional Committee, was killed in the encounter, the Naxalite movement in Gadchiroli no longer has a leadership.
# सतीश, नक्सलाइट डिव्हीजनल कमिटीचा सदस्य, संघर्षात मारला गेल्यामुळे गडचिरोलीतील नक्सलाइट आंदोलनाला आता कोणतीही नेतृत्व नाही.
# Of these, only 2,694 children between the ages of 1 and 10 are affected.
# यातून, केवळ २,६९४ वयोमर्यादेतील १ व १० वर्षांच्या वयोमर्यादेतील बालांना प्रभावित केले आहे.
# The third wave is expected to increase the incidence of child malnutrition.
# तिसरा लहर बाल दुर्बलता ची घटना वाढविणार अपेक्षित आहे.
# To submit a report to them, the health system compiled statistics on the number of children infected.
# त्यांना रिपोर्ट सबमिट करण्यासाठी, आरोग्य प्रणालीने लक्षणात आलेल्या बालांच्या संख्यांवर सांग्रहीत केलेले आकडे.
# However, according to pediatricians, the proportion should be 10 to 12 percent. I
# पण, बालरोगवैद्यांनुसार, तपासणी करण्याचं प्रमाण 10 ते 12 प्रतिशत असावं चाहिए.
# The proportion of those who need to be kept in the oxygen or intensive care unit is ten percent.
# ऑक्सीजन किंवा इंटेंसिव केअर इकाईत ठेवण्याची आवश्यकता असलेल्या लोकांचा प्रमाण दहा टक्के आहे.
# Young children get bored of using corona preventative measures, masks, sanitizers.
# कोरोना रोकण्याच्या उपायांचा वापर करण्यासाठी मुलांना अडचणी वाटते, जसे की मास्क, सॅनिटायझर्स.
# However, this ratio is not to be worried about, it is normal.
# पण हे अनुपात चिंतित करण्याची आवश्यकता नाही, हे सामान्य आहे.
# Most of these were also given remedicivir injections but were found to be of no use. T
# जिथे जिथे ही लोक रेमेडिसिव्हिर इंजेक्शन दिले गेले होते, तिथे त्यांना कोणत्याही फायद्याचे नसले त्याचीच माहिती मिळाली.
# Three thousand 515 of them have overcome the corona.
# तिन हजार पाचसपाच त्यांनी कोरोनाला मात दिलं आहे.
# While the number of tax-exempt persons has been found to be higher than the number of non-taxpayers who have been consistently seen on a daily basis for the past few days, the number of coronary addicts has once again been found to be slightly higher today.
# काही दिवसांपासून दररोजचे अपयशी व्यक्ती अधिक असल्याचे तपासले जाते, पण आज फिरलेल्या दिवसांपेक्षा काही सुधारित दिवसांपेक्षा हृदय रोगींची संख्या पुन्हा सोडली गेली आहे.
# As a result, the recovery rate of patients in the state has reached 92.76 per cent.
# त्याचा परिणामस्वरूप, राज्यातील रुग्णांची रिकव्हरी दर ९२.७६ प्रतिशत वर पोहोचली आहे.
# At present, there are 23,70,326 persons in Home Quarantine and 19,943 persons in Institutional Quarantine in the State.
# आता राज्यात गृह आवरणात 23,70,326 व्यक्ती आहेत आणि संस्थागत आवरणात 19,943 व्यक्ती आहेत.
# The Thackeray government had imposed strict restrictions on Karona and the lockdown was extended as the situation was not under control.
# ठाकरे सरकारने कोरोना विरुद्ध कठोर प्रतिबंध लागू केले होते आणि परिस्थिती त्याचा नियंत्रणात न असल्यामुळे लॉकडाऊन वाढविण्यात आला होता.
# Such doubts are beginning to come to the mind of the common man.
# सामान्य व्यक्तीच्या मनात ही अशंका सुरू होत आहे.
# He also said that the authority to negotiate has been given to a committee headed by the Chief Secretary.
# त्याने हीही सांगितलं की चरणीच्या अध्यक्षपदी असणार्या समितीला धारकार्य करण्याची अधिकारी दिलेली आहे.
# The state government should spend up to Rs 5 lakh for the treatment of this disease, fix the treatment fee for this disease, take action against the hospitals and doctors who charge more than this fee. ”
# राज्य सरकारने या रोगाच्या उपचारासाठी अधिकतम 5 लाख रुपये खर्च करण्यासाठी, या रोगाच्या उपचाराची फी निश्चित करण्यात आणि ही फीपेक्षा अधिक शुल्क वसूलणार्‍या अस्पतालांव डॉक्टरांवर कारवाई करण्यात यावी.”
# Only if all goes well can the Chief Minister and the Deputy Chief Minister discuss with the experts in the task force and consider easing the restrictions to some extent.
# केवळ जर सर्व काही चांगलं होतं तर मुख्यमंत्री आणि उपमुख्यमंत्री चर्चा करू शकतात ज्यामध्ये कार्यसमितीतील तज्ञांसह संवाद साधून काही प्रमाणातील प्रतिबंधांची कमी करण्याची विचार करू शकतात.
# These shops will be allowed to open on alternate days.
# हे दुकाने अनुक्रमांकित दिवसांवर उघडल्या जाईल.
# Hotels will be allowed to operate at 50 per cent capacity.
# हॉटेलला ५० प्रतिशत भरतीसाठी काम करण्याची परवानगी दिली जाईल.
# What changes should be made in the lockdown, which shops should be opened, AC shops, salons, electronics shops can be exempted from restrictions?
# लॉकडाऊनमध्ये कोणती परिस्थिती बदलाव्यात यात केल्यावे, कोणत्या दुकाने उघडाव्या यात केल्याव्या जाऊ शकतात, एसी दुकाने, सॅलॉन, इलेक्ट्रॉनिक्स दुकाने प्रतिबंधांपासून मोकळ्या केल्या जाऊ शकतात?
# He has also said that he will soon expose the corruption of this government.
# त्याने ही सरकारच्या भ्रष्टाचाराचा शीघ्र सुरुवात करणार असल्याचंही तो सांगितलं आहे.
# Why was the vaccine tender canceled?
# व्हॅक्सिन टेंडर काढून टाकला का?
# He has also harshly criticized the government for not having the mindset of the people and not being worthy of the post of Chief Minister.
# त्याने लोकांच्या मानसिकतेचा आणि मुख्यमंत्रीपदाच्या मौज्जी असल्याचे आरोप केले आहे की सरकारला कठोरपणे आलंय.
# He says, 'The ghost is on Matoshri, in the ministry. Make peace offerings there.'
# तो म्हणतो, 'भूत मातोश्रीवर आहे, मंत्रालयात. तिथे शांतीची बलिदाने करा.'
# Rane has also suggested that we should meet after recognizing our position in the party.
# राणे हीही सुचित्र केलं आहे की आपल्या पक्षातील आपली स्थिती ओळखून आपल्याला भेटु यावी, असे म्हणजे सुचवलं आहे.
# He also accused the Chief Minister of not giving anything to Konkan and not doing anything for the development of Konkan.
# त्याने त्याच्या आरोपात मुख्यमंत्रीला कोंकणला काहीही देत नाही आणि कोंकणची विकासासाठी काहीही करत नाही असे आरोप लागवले.
# For the last 20 days, lockouts, strict lockouts and strict action have been in force.
# शेवटच्या २० दिवसांपासून, लॉकआउट, कठोर लॉकआउट आणि कठोर कारवाई लागू आहे.
# So, 33 patients have died.
# त्यामध्ये ३३ रुग्ण मृत झाले आहेत.
# Satara district has 11 talukas.
# सातारा जिल्ह्यात ११ तालुके आहेत.
# Despite the lockout, despite the strict restrictions, the outbreak of corona infection has disturbed the sleep of the society.
# लॉकआउटच्या विरोधात, कठोर प्रतिबंधांमुळे, कोरोना संक्रमणाचा प्रसार समाजाच्या झोपाला अडचणी टाकली आहे.
# However, as the number of affected people in 18 districts including Thane is higher than the state average, the state government has decided to stop home segregation in all these districts.
# पण, ठाणे समाविष्ट १८ जिल्ह्यांतील प्रभावित लोकांची संख्या राज्यातील सरासरीपेक्षा अधिक आहे, त्यामुळे राज्य सरकारने त्यांच्यातील सर्व जिल्ह्यांतील घरी सेग्रेगेशन थांबवण्याचा निर्णय घेतला आहे.
# Corona outbreaks have been brought under control in half the districts of the state, including Mumbai, where the number of newly infected patients is declining rapidly.
# राज्यातील अर्ध्या जिल्ह्यांतील कोरोना प्रसाराचा तात्काळ नियंत्रणात आला आहे, जसे की मुंबई, जिथे नवीन संक्रमित रुग्णांची संख्या द्रुतपट घटत आहे.
# Therefore, it has been decided to close the house separation there.
# तसंच त्याचे घर विभाग त्यांच्याशी बंद करण्याचा निर्णय घेण्यात आला आहे.
# The number of patients undergoing treatment in the state has declined.
# राज्यात उपचारात असलेल्या रुग्णांची संख्या कमी झाली आहे.
# The government has issued a global tender to procure amphotericin B injection, which is required for the treatment of this disease.
# सरकारने ह्या रोगाच्या उपचारासाठी आवश्यक असलेल्या अंफोटेरिसिन बी इंजेक्शन खरेदी करण्यासाठी वैश्विक टेंडर जारी केला आहे.
# The company management has clarified in a press release that the security check mechanism relaxed during the coronation period is responsible for this and the company is not involved in the case.
# कंपनीचे व्यवस्थापन प्रेस विज्ञप्तीत स्पष्टपणे सांगितले आहे की राज्याभिषेक काळात सुरक्षा तपासणी विधान राहिल्यामुळे हा दोषी आहे आणि कंपनी यास जुळत नाही.
# However, the company management had refused to supply injections to the locals, saying that they were doing job work for a reputed company and that each original licensed company had to account for each injection.
# पण, कंपनीचे व्यवस्थापन स्थानिकांना इंजेक्शन पुरवण्याची नाकारली होती, म्हणून की त्यांनी एक प्रसिद्ध कंपनीसाठी काम करीत होतं आणि प्रत्येक मौल्यांकित कंपनीला प्रत्येक इंजेक्शनचा गुणाकार करावा लागतो.
# In this case, Nashik police has asked the company management to clarify its role and has requested documents and other information for investigation.
# या प्रकरणात, नाशिक पोलिसाने कंपनीच्या व्यवस्थापनाला त्याची भूमिका स्पष्ट करण्याची विनंती केली आहे आणि तपशील आणि तपशीलांसह तपासासाठी दस्तऐवज व इतर माहितीची विनंती केली आहे.
# The documents demanded by the police in this regard have been handed over and the company management is cooperating in the police investigation, the letter said.
# या संदर्भातील पोलीसांनी मागणी केलेले कागदपत्र सोडविले आहेत आणि कंपनीचे व्यवस्थापन पोलीसांच्या तपासात सहकार्य करीत आहे, हे पत्र म्हणते.
# On the one hand, even after the stock of more than 90 injections was reduced by the company which keeps track of each injection, why no complaint was lodged with the police immediately?
# एका हाताने, कंपनीने दर लाखाच्या अधिक इंजेक्शनची लसी वाढवली असताना पण पोलिसांना त्वरितपणे कोणत्याही तक्रार न केल्याचं कारण काय?
# According to the Health Ministry, 601 patients died due to corona in the state on Tuesday.
# आरोग्य मंत्रालयानुसार, मंगळवारी राज्यात कोरोनामुळे ६०१ रुग्णांची मृत्यू झाली.
# Therefore, today the number has finally reached 4 lakh 66 thousand 858.
# तसेच आज आंकडा अखेर 4 लाख 66 हजार 858 पर्यंत पोहोचला आहे.
# As a result, the total number of coroners has gone up to 6 lakh 99 thousand 904 till date.
# याचा परिणामस्वरूप, आजपर्यंत कॉरोनर्सची एकूण संख्या 6 लाख 99 हजार 904 वर पोहोचली आहे.
# Shortly after this decision, the commissioner of the Greater Mumbai Municipal Corporation informed that in Mumbai, however, house separation will be allowed.
# या निर्णयानंतर, मुंबईच्या महानगरपालिकेचे आयुक्त सूचित केले की मुंबईत, पण घराचा विभाग स्वीकृत केला जाईल.
# He said that there was a need to focus on institutional segregation, with a greater focus on rural areas.
# त्यांनी म्हणालं की संस्थागत विभाजनावर लक्ष देण्याची आवश्यकता आहे, त्यात ग्रामीण क्षेत्रांवर अधिक लक्ष देण्याची आवश्यकता आहे.
# All victims will be admitted to Covid Care Center.
# सर्व पीडितांना Covid केयर केंद्रात प्रवेश केला जाईल.
# However, some of the ventilators have gone beyond repair.
# पण काही व्हेंटिलेटर दुरुस्तीकरणाच्या बाहेर गेलेल्या आहेत.
# It also questions what needs to be done to address the issue.
# ह्या समस्येला समाधान करण्यासाठी काय करणे आवश्यक आहे हे सुचवते.
# The High Court has said that 37 of them are not in use yet.
# उच्च न्यायालयाने सांगितलं आहे की त्यांच्यामध्ये ३७ वापरले जात नाहीत.
# It is believed that ventilators are used to save lives and this poor ventilator can endanger the lives of patients, ”the High Court told Additional Solicitor General Ajay G. Talhar.
# विश्वास आहे की वेंटिलेटर्स जीवन उद्धार करण्यासाठी वापरले जातात आणि ही गरीब वेंटिलेटर रुग्णांच्या जीवनाची धोका देऊ शकते, ” उच्च न्यायालयाने अतिरिक्त सालिसिटर जनरल अजय जी. तलहारला सांगितलं.
# The court noted that 17 ventilators installed by GMCH had serious defects.
# न्यायालयाने नोंद केलं की जीएमसीएच द्वारे स्थापित केलेले १७ वेंटिलेटर्स गंभीर त्रुटी असल्या.
# evaluate_OpenAI-enmr-baseline.ipynb  pred.txt  src-test.txt  tgt-test.txt

# %%
# !pip3 install sacrebleu[ja]
# Out:
# Collecting sacrebleu[ja]
#   Downloading sacrebleu-2.4.1-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 1.4 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu[ja])
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ja]) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ja]) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ja]) (1.25.2)
# Collecting colorama (from sacrebleu[ja])
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ja]) (4.9.4)
# Collecting mecab-python3<=1.0.6,>=1.0.5 (from sacrebleu[ja])
#   Downloading mecab_python3-1.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (581 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.6/581.6 kB 6.8 MB/s eta 0:00:00
# Collecting ipadic<2.0,>=1.0 (from sacrebleu[ja])
#   Downloading ipadic-1.0.0.tar.gz (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 49.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ipadic
#   Building wheel for ipadic (setup.py) ... done
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556704 sha256=a3f959acad3780981fb121c797044a5ba9e22c6e0f3c0bd4b2c8fae23f6a58b8
#   Stored in directory: /root/.cache/pip/wheels/5b/ea/e3/2f6e0860a327daba3b030853fce4483ed37468bbf1101c59c3
# Successfully built ipadic
# Installing collected packages: mecab-python3, ipadic, portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 ipadic-1.0.0 mecab-python3-1.0.6 portalocker-2.8.2 sacrebleu-2.4.1

# %%
# to access sacrebleu help:
# !sacrebleu --help
# sentence level blue is too noisy. Uncomment if needed.
# !sacrebleu tgt-test.txt < pred.txt -m bleu -sl | tee -a experiment_log.txt
# !echo -e "+++ Evaluation Results for gpt-3.5-turbo-0125 ENGA Baseline +++ \n" | tee -a experiment_log.txt
# !echo "++ using sacrebleu ++" | tee -a experiment_log.txt

# !sacrebleu tgt-test.txt < pred.txt -m bleu --force | tee -a experiment_log.txt
# !sacrebleu tgt-test.txt < pred.txt -m bleu -lc --force \
  | tee -a experiment_log.txt

# !sacrebleu tgt-test.txt < pred.txt -m ter --force | tee -a experiment_log.txt
# !sacrebleu tgt-test.txt < pred.txt -m chrf --chrf-beta 1 --force \
| tee -a experiment_log.txt
# !sacrebleu tgt-test.txt < pred.txt -m chrf --chrf-beta 3 --force \
  | tee -a experiment_log.txt
# Out:
# +++ Evaluation Results for gpt-3.5-turbo-0125 ENGA Baseline +++
#
# ++ using sacrebleu ++
# {
#  "name": "BLEU",
#  "score": 6.7,
#  "signature": "nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1",
#  "verbose_score": "30.2/10.3/3.9/1.7 (BP = 1.000 ratio = 1.164 hyp_len = 8111 ref_len = 6970)",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.4.1"
# }
# {
#  "name": "BLEU",
#  "score": 6.7,
#  "signature": "nrefs:1|case:lc|eff:no|tok:13a|smooth:exp|version:2.4.1",
#  "verbose_score": "30.2/10.3/3.9/1.7 (BP = 1.000 ratio = 1.164 hyp_len = 8111 ref_len = 6970)",
#  "nrefs": "1",
#  "case": "lc",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.4.1"
# }
# {
#  "name": "TER",
#  "score": 105.5,
#  "signature": "nrefs:1|case:lc|tok:tercom|norm:no|punct:yes|asian:no|version:2.4.1",
#  "nrefs": "1",
#  "case": "lc",
#  "tok": "tercom",
#  "norm": "no",
#  "punct": "yes",
#  "asian": "no",
#  "version": "2.4.1"
# }
# {
#  "name": "chrF1",
#  "score": 37.1,
#  "signature": "nrefs:1|case:mixed|eff:yes|nc:6|nw:0|space:no|version:2.4.1",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "yes",
#  "nc": "6",
#  "nw": "0",
#  "space": "no",
#  "version": "2.4.1"
# }
# {
#  "name": "chrF3",
#  "score": 39.2,
#  "signature": "nrefs:1|case:mixed|eff:yes|nc:6|nw:0|space:no|version:2.4.1",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "yes",
#  "nc": "6",
#  "nw": "0",
#  "space": "no",
#  "version": "2.4.1"
# }
